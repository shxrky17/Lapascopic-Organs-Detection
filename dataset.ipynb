# %% [markdown]
# SCRIPT TO SPLIT IMAGES INTO  ORGAN FOLDERS

# %%
import os
import pandas as pd
import shutil

# === CONFIG ===
image_folder = '/home/yash/Desktop/project/train2'         # Flat folder with all images
csv_path = '/home/yash/Desktop/project/cdv/trrain2.csv'    # Original labels CSV
output_root = '/home/yash/Desktop/project/temp/t1'  # Output folder for organs only
new_csv_path = '/home/yash/Desktop/project/temp/new_train2.csv'  # Path for new filtered CSV

# Define a list of tool labels to exclude
tools_labels = [
    "TheOther_Instruments", "HarmonicAce_Head", "HarmonicAce_Body", "MarylandBipolarForceps_Head", 
    "MarylandBipolarForceps_Wrist", "CadiereForceps_Head", "CadiereForceps_Wrist", "CadiereForceps_Body", 
    "Specimenbag", "Stapler_Head", "Stapler_Body", "DrainTube", "Needle", "SmallClipApplier_Head", 
    "SmallClipApplier_Wrist", "SmallClipApplier_Body", "MediumLargeClipApplier_Head", 
    "MediumLargeClipApplier_Wrist", "MediumLargeClipApplier_Body", "SuctionIrrigation",
    "CurvedAtraumaticGrasper_Head", "CurvedAtraumaticGrasper_Body", "MarylandBipolarForceps_Body",
    "Endotip", "Gauze"
]

# Load CSV
df = pd.read_csv(csv_path)

# Clean filename
df['filename'] = df['filename'].apply(lambda x: os.path.basename(x))

# Convert label strings into lists
df['labels'] = df['labels'].apply(lambda x: [label.strip() for label in x.split(',')])

# Remove tool labels
df['labels'] = df['labels'].apply(lambda labels: [label for label in labels if label not in tools_labels])

# Filter out rows with no valid labels
df = df[df['labels'].apply(len) > 0]

# Deduplicate labels per image
df = df.groupby('filename')['labels'].sum().reset_index()
df['labels'] = df['labels'].apply(lambda x: list(set(x)))

# Save new master label CSV
df['labels'] = df['labels'].apply(lambda x: ','.join(x))  # Convert list back to comma-separated string
df.to_csv(new_csv_path, index=False)
print(f"📄 New label CSV saved to: {new_csv_path}")

# Split images into label folders
for _, row in df.iterrows():
    filename = row['filename']
    labels = row['labels'].split(',')  # Now stored as string in CSV
    src_path = os.path.join(image_folder, filename)

    if not os.path.exists(src_path):
        print(f"⚠️  Warning: {filename} not found in image folder, skipping.")
        continue

    for label in labels:
        label_folder = os.path.join(output_root, label)
        os.makedirs(label_folder, exist_ok=True)

        dst_path = os.path.join(label_folder, filename)
        if not os.path.exists(dst_path):
            shutil.copy(src_path, dst_path)

        # Update class-specific CSV too
        label_csv_path = os.path.join(label_folder, 'labels.csv')
        with open(label_csv_path, 'a') as f:
            f.write(f"{filename},{','.join(labels)}\n")

print("✅ Dataset reorganized. Tool labels excluded. New master CSV created.")
# Out:
# 📄 New label CSV saved to: /home/yash/Desktop/project/temp/new_train2.csv
# ✅ Dataset reorganized. Tool labels excluded. New master CSV created.

# %% [markdown]
# AUGMENTATION(UPSAMPLE) SCRIPT

# %%
import os
import random
import pandas as pd
from PIL import Image
from torchvision import transforms
import warnings

# === CONFIG ===
image_folder = '/home/yash/Desktop/project/new dataset/train3/TheOther_Tissues'  # Gallbladder images only
csv_path = '/home/yash/Desktop/project/new dataset/train3/TheOther_Tissues/new_train3.csv'  # Original labels CSV
num_to_generate = 1  # Number of augmented images

# Output folder (same as the original Gallbladder folder)
output_folder = image_folder

# --- Robust CSV Loading ---
def load_csv(csv_path):
    try:
        df = pd.read_csv(csv_path)
    except pd.errors.ParserError as e:
        warnings.warn(f"ParserError: {e}\nTrying to load with on_bad_lines='skip'.")
        df = pd.read_csv(csv_path, on_bad_lines='skip')
    return df

df = load_csv(csv_path)

# --- Check and Fix Columns ---
expected_columns = ['filename', 'labels']
if not all(col in df.columns for col in expected_columns):
    print(f"❌ CSV columns found: {df.columns.tolist()}")
    raise ValueError(f"CSV must contain columns: {expected_columns}")

# Normalize filename and labels columns
df['filename'] = df['filename'].apply(lambda x: os.path.basename(str(x)))
df['labels'] = df['labels'].apply(lambda x: [label.strip() for label in str(x).split(',')])

# Remove entries with missing image files
initial_count = len(df)
df = df[df['filename'].apply(lambda f: os.path.exists(os.path.join(image_folder, f)))]
removed = initial_count - len(df)
print(f"🧹 Removed {removed} entries pointing to missing image files.")

# Filter for Gallbladder images
gallbladder_df = df[df['labels'].apply(lambda labels: 'Gallbladder' in labels)].reset_index(drop=True)

# --- Check for images ---
image_files = gallbladder_df['filename'].tolist()
if not image_files:
    raise ValueError("No Gallbladder images found in the dataset.")

# --- Augmentation Pipeline ---
augment = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(20),
    transforms.ColorJitter(brightness=0.2, contrast=0.2),
])

# --- Store new label entries ---
labels = []

# Add original entries (with full label set)
for _, row in gallbladder_df.iterrows():
    labels.append({'filename': row['filename'], 'labels': ','.join(row['labels'])})

# --- Generate augmented images ---
for i in range(num_to_generate):
    row = gallbladder_df.sample(n=1).iloc[0]
    original_file = row['filename']
    original_labels = row['labels']
    original_path = os.path.join(image_folder, original_file)

    # Open and augment image
    img = Image.open(original_path).convert('RGB')
    aug_img = augment(img)

    # Generate unique filename for each augmentation
    aug_filename = f"aug_{i}_{original_file}"
    aug_path = os.path.join(output_folder, aug_filename)

    # Save image
    aug_img.save(aug_path)

    # Save label record
    labels.append({'filename': aug_filename, 'labels': ','.join(original_labels)})

# --- Write updated labels to CSV ---
df_new = pd.DataFrame(labels)
df_new.to_csv(csv_path, index=False)

print(f"✅ Augmentation complete: {num_to_generate} new images.")
print(f"📄 CSV updated at: {csv_path}")
# Out:
# 🧹 Removed 1 entries pointing to missing image files.
# ✅ Augmentation complete: 1 new images.
# 📄 CSV updated at: /home/yash/Desktop/project/new dataset/train3/TheOther_Tissues/new_train3.csv

# %%
import os
import shutil
import pandas as pd
from collections import defaultdict

# === MANUAL CONFIGURATION ===
organ_image_folders = [
    "/home/yash/Desktop/project/new dataset/train3/Gallbladder",
    "/home/yash/Desktop/project/new dataset/train3/Liver",
    "/home/yash/Desktop/project/new dataset/train3/Pancreas",
    "/home/yash/Desktop/project/new dataset/train3/Stomach",
    "/home/yash/Desktop/project/new dataset/train3/Spleen",
    "/home/yash/Desktop/project/new dataset/train3/TheOther_Tissues",
    
]

organ_label_csvs = [
    "/home/yash/Desktop/project/new dataset/train3/Gallbladder/new_train3.csv",
    "/home/yash/Desktop/project/new dataset/train3/Liver/new_train3.csv",
    "/home/yash/Desktop/project/new dataset/train3/Pancreas/new_train3.csv",
    "/home/yash/Desktop/project/new dataset/train3/Stomach/new_train3.csv",
    "/home/yash/Desktop/project/new dataset/train3/Spleen/new_train3.csv",
    "/home/yash/Desktop/project/new dataset/train3/TheOther_Tissues/new_train3.csv",
    
]

# Output paths
OUTPUT_IMG_DIR = "/home/yash/Desktop/project/new dataset/ft3"
OUTPUT_CSV_PATH = "/home/yash/Desktop/project/new dataset/ft3/main_labels.csv"
LOG_PATH = "/home/yash/Desktop/project/new dataset/ft3/merge_log.txt"

# Create output folder if not exists
os.makedirs(OUTPUT_IMG_DIR, exist_ok=True)

# Tracker for duplicate filenames
filename_counter = defaultdict(int)
final_rows = []
log_lines = []

# === MERGING ===
for images_dir, labels_csv_path in zip(organ_image_folders, organ_label_csvs):
    if not os.path.exists(labels_csv_path):
        log_lines.append(f"❌ Missing CSV: {labels_csv_path}")
        continue
    if not os.path.exists(images_dir):
        log_lines.append(f"❌ Missing image folder: {images_dir}")
        continue

    df = pd.read_csv(labels_csv_path)

    for _, row in df.iterrows():
        original_filename = row['filename'].strip()
        labels = row['labels'].strip()

        # Ensure filenames are unique by appending a count if needed
        filename_base, ext = os.path.splitext(original_filename)
        count = filename_counter[original_filename]
        new_filename = original_filename if count == 0 else f"{filename_base}_{count}{ext}"
        filename_counter[original_filename] += 1

        # Define source and destination paths
        src_img_path = os.path.join(images_dir, original_filename)
        dst_img_path = os.path.join(OUTPUT_IMG_DIR, new_filename)

        if os.path.exists(src_img_path):
            # Copy the image to the destination folder
            shutil.copy(src_img_path, dst_img_path)
            final_rows.append((new_filename, labels))

            # Log if a duplicate filename is used
            if new_filename != original_filename:
                log_lines.append(f"Duplicated: {original_filename} → {new_filename} | Labels: {labels}")
        else:
            # Log the missing image warning
            warning_msg = f"⚠️ Missing image: {src_img_path}"
            print(warning_msg)
            log_lines.append(warning_msg)

# Write the merged CSV with the final image labels
with open(OUTPUT_CSV_PATH, 'w') as f:
    f.write("filename,labels\n")
    for filename, labels in final_rows:
        f.write(f"{filename},{labels}\n")

# Write the log file for duplicate handling and missing images
with open(LOG_PATH, 'w') as log_file:
    log_file.write("=== Duplicate Image Merge Log ===\n")
    for line in log_lines:
        log_file.write(line + "\n")

# Summary output
print(f"\n✅ All images (including duplicates) saved to: {OUTPUT_IMG_DIR}")
print(f"✅ Merged CSV written to: {OUTPUT_CSV_PATH}")
print(f"📝 Log file saved to: {LOG_PATH}")
# Out:
# ✅ All images (including duplicates) saved to: /home/yash/Desktop/project/new dataset/ft3
# ✅ Merged CSV written to: /home/yash/Desktop/project/new dataset/ft3/main_labels.csv
# 📝 Log file saved to: /home/yash/Desktop/project/new dataset/ft3/merge_log.txt

# %% [markdown]
# SCRIPT TO MERGE FOLDERS

# %%
import os
import shutil
import pandas as pd
from collections import defaultdict

# === MANUAL CONFIGURATION ===
organ_image_folders = [
    "/home/yash/Desktop/project/new dataset/train1/Gallbladder",
    "/home/yash/Desktop/project/new dataset/train1/Liver",
    "/home/yash/Desktop/project/new dataset/train1/Pancreas",
    "/home/yash/Desktop/project/new dataset/train1/Stomach",
    "/home/yash/Desktop/project/new dataset/train1/TheOther_Tissues",
    "/home/yash/Desktop/project/new dataset/train1/Spleen"
]

organ_label_csvs = [
    "/home/yash/Desktop/project/new dataset/train1/Gallbladder/new_train1.csv",
    "/home/yash/Desktop/project/new dataset/train1/Liver/new_train1.csv",
    "/home/yash/Desktop/project/new dataset/train1/Pancreas/new_train1.csv",
    "/home/yash/Desktop/project/new dataset/train1/Stomach/new_train1.csv",
    "/home/yash/Desktop/project/new dataset/train1/TheOther_Tissues/new_train1.csv",
    "/home/yash/Desktop/project/new dataset/train1/Spleen/new_train1.csv"
]

# Output paths
OUTPUT_IMG_DIR = "/home/yash/Desktop/project/new dataset/ft1"
OUTPUT_CSV_PATH = "/home/yash/Desktop/project/new dataset/ft1/main_labels.csv"
LOG_PATH = "/home/yash/Desktop/project/new dataset/ft1/merge_log.txt"

# Create output folder if not exists
os.makedirs(OUTPUT_IMG_DIR, exist_ok=True)

# Tracker for duplicate filenames
filename_counter = defaultdict(int)
final_rows = []
log_lines = []

# === MERGING ===
for images_dir, labels_csv_path in zip(organ_image_folders, organ_label_csvs):
    if not os.path.exists(labels_csv_path):
        log_lines.append(f"❌ Missing CSV: {labels_csv_path}")
        continue
    if not os.path.exists(images_dir):
        log_lines.append(f"❌ Missing image folder: {images_dir}")
        continue

    # Read the CSV for labels
    df = pd.read_csv(labels_csv_path)

    # Log for checking if the file exists
    for _, row in df.iterrows():
        original_filename = row['filename']
        labels = row['labels'].strip()
        image_path = os.path.join(images_dir, original_filename)

        # Check if the file exists in the organ folder
        if os.path.exists(image_path):
            print(f"Found image: {original_filename} in {images_dir}")
        else:
            print(f"⚠️ Image not found: {original_filename} in {images_dir}")

        # Handle filename uniqueness
        filename_base, ext = os.path.splitext(original_filename)
        count = filename_counter[original_filename]
        new_filename = original_filename if count == 0 else f"{filename_base}_{count}{ext}"
        filename_counter[original_filename] += 1

        # Source and destination paths for images
        src_img_path = os.path.join(images_dir, original_filename)
        dst_img_path = os.path.join(OUTPUT_IMG_DIR, new_filename)

        if os.path.exists(src_img_path):
            shutil.copy(src_img_path, dst_img_path)
            final_rows.append((new_filename, labels))

            # Log duplicate filenames
            if new_filename != original_filename:
                log_lines.append(f"Duplicated: {original_filename} → {new_filename} | Labels: {labels}")
        else:
            warning_msg = f"⚠️ Missing image: {src_img_path}"
            print(warning_msg)
            log_lines.append(warning_msg)

# Write the merged CSV with the final image labels
with open(OUTPUT_CSV_PATH, 'w') as f:
    f.write("filename,labels\n")
    for filename, labels in final_rows:
        f.write(f"{filename},{labels}\n")

# Write the log file for duplicate handling and missing images
with open(LOG_PATH, 'w') as log_file:
    log_file.write("=== Duplicate Image Merge Log ===\n")
    for line in log_lines:
        log_file.write(line + "\n")

# Summary output
print(f"\n✅ All images (including duplicates) saved to: {OUTPUT_IMG_DIR}")
print(f"✅ Merged CSV written to: {OUTPUT_CSV_PATH}")
print(f"📝 Log file saved to: {LOG_PATH}")
# Out:
# Found image: R001_ch1_video_01_00-15-18-17.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R001_ch1_video_01_00-15-45-29.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R001_ch1_video_01_00-19-55-03.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R001_ch1_video_01_00-21-47-07.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R001_ch1_video_01_00-22-06-28.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R001_ch1_video_01_00-26-29-12.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R001_ch1_video_01_00-30-42-07.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R001_ch1_video_01_00-53-21-03.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R001_ch1_video_01_00-56-00-11.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R001_ch1_video_01_00-57-14-18.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R001_ch1_video_01_00-57-14-23.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R001_ch1_video_01_00-57-36-10.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R001_ch1_video_01_00-57-58-10.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R001_ch1_video_01_01-02-30-09.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R001_ch1_video_01_01-10-49-01.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R001_ch1_video_01_01-10-53-01.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R001_ch1_video_01_01-11-41-09.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R001_ch1_video_01_01-11-51-01.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R001_ch1_video_01_01-12-00-18.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R001_ch1_video_01_01-12-18-09.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R001_ch1_video_01_01-12-47-27.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R001_ch1_video_01_01-13-08-07.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R001_ch1_video_03_00-15-41-20.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R001_ch1_video_03_00-51-57-23.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R001_ch1_video_03_00-52-00-17.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R001_ch1_video_03_00-55-04-15.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R001_ch1_video_03_00-55-30-07.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R001_ch1_video_03_00-57-53-26.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R001_ch1_video_03_01-00-36-26.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R001_ch1_video_03_01-01-48-04.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R001_ch1_video_03_01-04-03-09.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R001_ch1_video_03_01-11-44-17.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R001_ch1_video_03_01-11-46-17.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R001_ch1_video_03_01-11-51-25.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R001_ch1_video_03_01-11-57-19.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R001_ch1_video_03_01-12-03-10.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R001_ch1_video_03_01-13-02-01.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R001_ch1_video_03_01-13-30-01.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R001_ch1_video_03_01-14-08-01.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R001_ch1_video_03_01-14-08-12.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R002_ch1_video_01_00-04-52-18.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R002_ch1_video_01_00-07-04-09.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R002_ch1_video_01_00-12-30-09.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R002_ch1_video_01_00-14-09-09.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R002_ch1_video_01_00-14-10-11.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R002_ch1_video_01_00-14-11-09.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R002_ch1_video_01_00-14-16-09.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R002_ch1_video_01_00-16-31-09.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R002_ch1_video_01_00-38-24-12.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R002_ch1_video_01_00-38-39-23.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R002_ch1_video_01_00-41-27-13.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R002_ch1_video_01_00-41-38-11.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R002_ch1_video_01_00-41-54-26.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R002_ch1_video_01_00-47-49-15.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R002_ch1_video_01_00-49-11-28.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R002_ch1_video_01_00-54-08-08.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R002_ch1_video_01_00-54-12-12.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R002_ch1_video_01_00-56-30-29.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R002_ch1_video_01_00-58-20-11.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R002_ch1_video_01_00-58-34-28.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R002_ch1_video_01_00-58-41-13.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R002_ch1_video_01_00-58-54-01.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R002_ch1_video_01_00-59-00-27.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R002_ch1_video_01_00-59-35-06.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R002_ch1_video_01_01-00-13-01.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R002_ch1_video_01_01-04-17-11.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R002_ch1_video_01_01-06-56-20.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R002_ch1_video_01_01-07-25-19.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R002_ch1_video_03_00-18-15-21.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R002_ch1_video_03_00-20-26-17.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R002_ch1_video_03_00-25-08-15.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R002_ch1_video_03_00-27-41-24.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R002_ch1_video_03_00-29-25-02.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R002_ch1_video_03_00-29-36-00.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R002_ch1_video_03_00-29-38-16.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R002_ch1_video_03_00-29-50-01.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R002_ch1_video_03_00-30-32-18.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R002_ch1_video_03_00-30-43-18.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R002_ch1_video_03_00-33-18-12.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R002_ch1_video_03_00-40-26-12.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R002_ch1_video_03_00-40-31-13.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R002_ch1_video_03_00-40-36-02.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R002_ch1_video_03_00-40-41-21.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R002_ch1_video_03_00-40-46-13.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R002_ch1_video_03_00-40-47-29.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R002_ch1_video_03_00-40-52-30.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R002_ch1_video_03_00-41-02-20.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R002_ch1_video_03_00-41-17-13.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R005_ch1_video_01_00-03-28-01.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R005_ch1_video_01_00-19-26-06.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R005_ch1_video_01_00-22-00-06.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R005_ch1_video_01_00-22-57-00.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R005_ch1_video_01_00-23-03-09.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R005_ch1_video_01_00-23-08-13.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R005_ch1_video_01_00-24-18-18.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R005_ch1_video_01_00-24-56-18.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R005_ch1_video_01_00-38-56-22.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R005_ch1_video_01_00-43-10-14.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R005_ch1_video_01_00-48-51-24.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R005_ch1_video_01_00-48-56-25.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R005_ch1_video_01_00-49-08-29.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R005_ch1_video_01_00-49-16-00.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R005_ch1_video_01_00-49-32-21.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R005_ch1_video_03_00-02-12-15.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R005_ch1_video_03_00-05-34-14.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R005_ch1_video_03_00-09-09-17.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R005_ch1_video_03_00-10-46-28.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R005_ch1_video_03_00-12-15-04.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R005_ch1_video_03_00-18-52-00.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R005_ch1_video_03_00-18-54-00.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R005_ch1_video_03_00-18-54-17.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R005_ch1_video_03_00-19-00-02.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R005_ch1_video_03_00-19-05-02.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R005_ch1_video_03_00-19-10-11.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R005_ch1_video_03_00-19-30-11.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R007_ch1_video_01_00-10-53-18.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R007_ch1_video_01_00-46-44-27.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R007_ch1_video_01_00-47-12-28.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R007_ch1_video_01_00-47-24-03.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R007_ch1_video_01_00-47-30-03.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R007_ch1_video_01_00-47-54-03.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R007_ch1_video_01_01-02-22-22.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R007_ch1_video_01_01-09-17-26.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R007_ch1_video_04_00-14-38-12.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R010_ch1_video_01_00-00-57-20.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R010_ch1_video_01_00-06-53-11.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R010_ch1_video_01_00-32-07-14.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R010_ch1_video_01_00-32-19-22.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R010_ch1_video_01_00-32-23-23.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R010_ch1_video_01_00-37-51-25.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R010_ch1_video_01_00-38-04-25.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R010_ch1_video_01_00-38-19-25.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R010_ch1_video_01_00-40-30-25.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R010_ch1_video_01_00-40-34-20.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R010_ch1_video_01_00-40-39-20.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R010_ch1_video_01_00-40-52-22.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R010_ch1_video_01_00-41-03-04.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R010_ch1_video_03_00-20-32-26.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R010_ch1_video_03_00-24-40-05.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R010_ch1_video_03_00-25-12-14.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R010_ch1_video_03_00-25-18-05.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R010_ch1_video_03_00-25-18-07.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R010_ch1_video_03_00-25-25-05.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R010_ch1_video_03_00-26-28-05.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R010_ch1_video_03_00-26-28-08.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R010_ch1_video_03_00-26-34-19.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R010_ch1_video_03_00-26-35-05.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R010_ch1_video_03_00-26-39-20.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R014_ch1_video_01_00-02-14-14.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R014_ch1_video_01_00-10-50-04.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R014_ch1_video_01_00-16-35-14.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R014_ch1_video_01_00-27-56-14.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R014_ch1_video_01_00-37-51-06.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R014_ch1_video_01_00-37-54-10.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R014_ch1_video_01_00-37-59-10.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R014_ch1_video_01_00-38-02-10.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R014_ch1_video_01_00-38-07-10.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R014_ch1_video_01_00-38-12-10.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R014_ch1_video_01_00-38-17-10.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R014_ch1_video_01_00-38-20-07.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R014_ch1_video_01_00-38-22-11.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R014_ch1_video_01_00-38-27-10.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R014_ch1_video_01_00-38-33-10.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R014_ch1_video_01_00-38-40-10.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R014_ch1_video_01_00-38-42-10.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R014_ch1_video_01_00-38-44-10.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R014_ch1_video_01_00-38-49-10.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R014_ch1_video_03_00-06-28-22.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R014_ch1_video_03_00-07-49-22.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R014_ch1_video_03_00-10-58-22.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R014_ch1_video_03_00-12-14-22.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R014_ch1_video_03_00-18-01-22.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R014_ch1_video_03_00-23-05-03.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R014_ch1_video_03_00-23-12-03.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R014_ch1_video_03_00-23-17-03.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R014_ch1_video_03_00-23-24-04.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R014_ch1_video_03_00-23-34-05.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R014_ch1_video_03_00-23-42-05.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R014_ch1_video_03_00-23-59-05.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R014_ch1_video_03_00-24-31-18.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R014_ch1_video_03_00-27-26-05.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R014_ch1_video_03_00-51-16-20.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R014_ch1_video_03_00-55-29-16.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R014_ch1_video_03_00-59-31-16.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R014_ch1_video_03_01-03-19-26.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R014_ch1_video_03_01-03-25-04.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R014_ch1_video_03_01-03-31-13.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R014_ch1_video_03_01-03-37-17.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R014_ch1_video_03_01-03-43-17.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R014_ch1_video_03_01-14-13-20.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R014_ch1_video_03_01-14-19-09.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R014_ch1_video_03_01-14-19-20.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R014_ch1_video_03_01-14-24-10.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R014_ch1_video_03_01-14-29-10.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R014_ch1_video_03_01-14-34-13.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R014_ch1_video_03_01-14-39-13.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R014_ch1_video_03_01-14-44-17.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R015_ch1_video_01_00-19-33-25.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R015_ch1_video_01_00-24-36-19.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R015_ch1_video_01_00-40-06-07.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R015_ch1_video_01_00-40-27-24.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R015_ch1_video_01_00-41-52-26.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R015_ch1_video_01_00-55-11-29.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R015_ch1_video_01_00-56-51-13.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R015_ch1_video_01_00-57-06-15.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R015_ch1_video_01_00-57-23-16.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R015_ch1_video_01_00-57-31-08.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R015_ch1_video_01_01-00-45-07.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R015_ch1_video_03_00-18-54-08.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R015_ch1_video_03_00-31-22-20.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R015_ch1_video_03_00-33-49-22.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R015_ch1_video_03_00-36-35-25.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R015_ch1_video_03_00-36-38-25.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R015_ch1_video_03_00-36-40-25.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R015_ch1_video_03_00-36-45-25.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R015_ch1_video_03_00-36-47-27.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R015_ch1_video_03_00-36-50-25.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R015_ch1_video_03_00-36-54-27.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R015_ch1_video_03_00-36-55-25.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R015_ch1_video_03_00-37-00-25.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R015_ch1_video_03_00-37-03-25.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R015_ch1_video_03_00-37-34-26.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R015_ch1_video_03_00-37-36-26.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R015_ch1_video_03_00-37-42-16.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R015_ch1_video_03_00-37-43-24.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R015_ch1_video_03_00-37-58-02.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R015_ch1_video_03_00-38-09-02.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R015_ch1_video_03_00-39-14-12.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R015_ch1_video_03_00-39-16-06.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R015_ch1_video_03_00-39-18-12.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R015_ch1_video_03_00-39-52-06.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R019_ch1_video_01_00-17-26-27.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R019_ch1_video_01_00-18-41-12.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R019_ch1_video_01_00-20-50-21.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R019_ch1_video_01_00-20-59-28.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R019_ch1_video_01_00-48-37-20.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R019_ch1_video_01_00-52-29-09.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R019_ch1_video_01_00-58-37-26.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R019_ch1_video_01_00-58-47-23.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R019_ch1_video_01_00-59-09-10.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R019_ch1_video_03_00-33-26-10.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R019_ch1_video_03_00-43-37-13.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R019_ch1_video_05_00-04-47-19.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R019_ch1_video_05_00-07-34-20.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R019_ch1_video_05_00-11-02-05.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R019_ch1_video_05_00-11-10-16.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R019_ch1_video_05_00-11-19-07.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R019_ch1_video_05_00-11-23-08.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R019_ch1_video_05_00-11-27-28.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R019_ch1_video_05_00-13-41-17.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R019_ch1_video_05_00-14-07-19.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R048_ch1_video_01_00-08-42-14.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R048_ch1_video_01_00-08-51-23.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R048_ch1_video_01_00-22-10-28.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R048_ch1_video_01_00-23-03-03.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R048_ch1_video_01_00-31-22-05.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R048_ch1_video_02_00-11-41-16.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R048_ch1_video_02_00-13-46-15.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R048_ch1_video_02_00-14-12-08.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R048_ch1_video_02_00-41-03-29.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R048_ch1_video_02_00-47-52-00.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R048_ch1_video_02_00-49-18-24.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R056_ch1_video_01_00-04-41-28.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R056_ch1_video_01_00-08-44-09.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R056_ch1_video_01_00-22-21-25.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R056_ch1_video_01_00-24-39-15.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R056_ch1_video_01_00-35-52-21.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R056_ch1_video_01_00-39-00-26.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R056_ch1_video_01_00-39-18-04.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R056_ch1_video_01_00-39-19-19.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R056_ch1_video_01_00-39-45-20.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R056_ch1_video_03_00-06-49-01.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R074_ch1_video_01_00-03-24-20.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R074_ch1_video_01_00-03-38-07.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R074_ch1_video_01_00-03-57-10.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R074_ch1_video_01_00-04-18-07.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R074_ch1_video_01_00-04-41-00.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R074_ch1_video_01_00-07-20-03.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R074_ch1_video_01_00-08-57-13.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R074_ch1_video_01_00-28-30-08.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R074_ch1_video_01_00-52-54-22.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R074_ch1_video_01_00-52-54-24.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R074_ch1_video_01_00-53-15-24.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R074_ch1_video_01_00-53-27-25.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R074_ch1_video_03_00-19-15-22.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R074_ch1_video_03_00-22-38-06.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R074_ch1_video_03_00-23-03-08.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R074_ch1_video_03_00-58-25-06.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R074_ch1_video_03_00-59-00-06.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R076_ch1_video_01_00-00-00-25.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R076_ch1_video_01_00-01-12-19.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R076_ch1_video_01_00-07-43-21.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R076_ch1_video_01_00-09-20-13.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R076_ch1_video_01_00-09-50-10.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R076_ch1_video_01_00-10-07-00.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R076_ch1_video_01_00-10-09-04.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R076_ch1_video_01_00-12-57-19.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R076_ch1_video_01_00-34-15-03.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R076_ch1_video_01_00-45-38-05.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R076_ch1_video_01_00-46-03-08.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R076_ch1_video_01_00-53-01-23.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R076_ch1_video_01_00-54-28-03.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R076_ch1_video_01_00-54-38-20.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R076_ch1_video_01_00-54-41-22.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R076_ch1_video_01_00-54-44-11.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R076_ch1_video_03_00-02-10-06.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R076_ch1_video_03_00-07-09-07.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R076_ch1_video_03_00-07-10-22.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R076_ch1_video_03_00-18-53-06.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R076_ch1_video_03_00-28-16-08.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R076_ch1_video_03_00-31-44-28.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R076_ch1_video_03_00-33-04-27.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R076_ch1_video_03_00-33-07-07.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R076_ch1_video_03_00-33-09-00.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R076_ch1_video_03_00-33-11-09.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R076_ch1_video_03_00-33-22-00.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R076_ch1_video_03_00-33-26-00.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R076_ch1_video_03_00-33-38-00.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R076_ch1_video_03_00-33-55-06.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R076_ch1_video_03_00-35-45-24.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R076_ch1_video_03_00-41-20-16.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R084_ch1_video_01_00-00-59-24.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R084_ch1_video_01_00-01-03-19.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R084_ch1_video_01_00-01-08-05.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R084_ch1_video_01_00-01-10-25.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R084_ch1_video_01_00-01-53-25.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R084_ch1_video_01_00-06-33-08.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R084_ch1_video_01_00-07-13-14.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R084_ch1_video_01_00-07-28-08.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R084_ch1_video_01_00-07-31-25.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R084_ch1_video_01_00-07-33-12.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R084_ch1_video_01_00-07-41-02.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R084_ch1_video_01_00-09-31-12.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R084_ch1_video_01_01-15-49-26.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R084_ch1_video_03_00-02-27-12.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R084_ch1_video_03_00-02-28-14.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R084_ch1_video_03_00-03-01-09.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R084_ch1_video_03_00-03-05-15.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R084_ch1_video_03_00-05-26-12.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R084_ch1_video_03_00-07-05-13.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R084_ch1_video_03_00-09-45-12.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R084_ch1_video_03_00-10-36-18.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R084_ch1_video_03_00-11-01-18.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R084_ch1_video_03_00-36-32-19.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R084_ch1_video_03_00-36-35-12.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R084_ch1_video_03_00-41-31-14.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R084_ch1_video_03_00-41-35-16.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R084_ch1_video_03_00-43-01-16.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R084_ch1_video_03_00-44-19-01.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R084_ch1_video_03_00-47-28-17.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R084_ch1_video_03_00-57-31-04.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R084_ch1_video_03_00-57-39-16.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R084_ch1_video_03_00-57-44-25.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R084_ch1_video_03_00-57-47-18.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R084_ch1_video_03_00-58-33-12.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R084_ch1_video_03_00-59-23-00.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R084_ch1_video_03_00-59-39-16.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R084_ch1_video_03_00-59-53-19.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R094_ch1_video_01_00-05-09-01.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R094_ch1_video_01_00-05-29-16.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R094_ch1_video_01_00-05-30-06.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R094_ch1_video_01_00-38-15-05.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R094_ch1_video_01_00-38-48-27.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R094_ch1_video_01_01-10-37-17.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R094_ch1_video_01_01-13-04-13.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R094_ch1_video_01_01-14-37-07.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R094_ch1_video_01_01-14-52-29.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R094_ch1_video_03_00-00-10-05.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R094_ch1_video_03_00-00-37-19.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R094_ch1_video_03_00-00-37-29.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R094_ch1_video_03_00-00-40-19.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R094_ch1_video_03_00-00-45-19.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R094_ch1_video_03_00-00-56-19.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R094_ch1_video_03_00-01-03-19.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R094_ch1_video_03_00-02-01-17.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R094_ch1_video_03_00-02-09-19.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R100_ch1_video_01_00-02-21-26.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R100_ch1_video_01_00-02-23-27.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R100_ch1_video_01_00-07-38-02.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R100_ch1_video_01_00-33-09-27.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R100_ch1_video_01_00-33-21-03.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R100_ch1_video_01_00-33-48-07.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R100_ch1_video_01_00-33-50-06.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R100_ch1_video_01_00-47-41-16.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R100_ch1_video_01_00-48-54-07.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R100_ch1_video_01_00-49-23-05.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R100_ch1_video_01_00-49-35-21.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R100_ch1_video_01_00-49-39-11.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R100_ch1_video_01_01-14-57-07.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R100_ch1_video_01_01-15-03-07.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R100_ch1_video_03_00-18-31-11.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R100_ch1_video_03_00-54-40-00.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R117_ch1_video_01_00-00-11-25.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R117_ch1_video_01_00-00-16-04.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R117_ch1_video_01_00-02-50-28.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R117_ch1_video_01_00-03-15-03.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R117_ch1_video_01_00-31-04-11.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R117_ch1_video_01_00-39-23-10.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R117_ch1_video_01_00-47-00-13.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R117_ch1_video_01_00-51-26-10.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R117_ch1_video_01_00-51-39-27.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R117_ch1_video_01_00-51-42-10.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R117_ch1_video_01_00-52-05-19.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R117_ch1_video_01_00-52-06-12.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R117_ch1_video_01_00-54-15-17.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R117_ch1_video_01_00-54-16-12.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R117_ch1_video_01_00-54-18-00.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R117_ch1_video_01_00-54-29-02.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R117_ch1_video_03_00-17-35-21.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R117_ch1_video_03_00-23-58-01.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R117_ch1_video_03_00-24-14-00.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R117_ch1_video_03_00-24-20-24.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R117_ch1_video_03_00-26-41-24.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R117_ch1_video_03_00-29-07-27.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R117_ch1_video_03_00-33-19-23.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R117_ch1_video_03_00-34-13-14.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R117_ch1_video_03_00-34-45-04.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R117_ch1_video_03_00-35-21-03.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R117_ch1_video_03_00-35-36-01.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R117_ch1_video_03_00-35-36-02.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R117_ch1_video_03_00-35-39-01.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R117_ch1_video_03_00-35-42-01.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R117_ch1_video_03_00-35-44-02.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R117_ch1_video_03_00-35-47-01.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R117_ch1_video_03_00-35-55-29.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R117_ch1_video_03_00-35-56-02.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R117_ch1_video_03_00-35-58-04.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R117_ch1_video_03_00-36-04-00.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R117_ch1_video_03_00-36-12-14.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R117_ch1_video_03_00-38-19-07.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R201_ch1_video_01_00-26-56-07.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R201_ch1_video_01_00-33-38-04.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R201_ch1_video_03_00-07-42-07.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R201_ch1_video_03_00-07-43-11.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R201_ch1_video_03_00-24-59-28.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R201_ch1_video_03_00-25-16-11.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R201_ch1_video_03_00-26-30-25.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R201_ch1_video_03_00-27-07-22.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R201_ch1_video_03_00-27-10-23.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R201_ch1_video_03_00-27-19-22.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R201_ch1_video_03_00-27-31-09.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R201_ch1_video_03_00-27-57-02.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R201_ch1_video_03_00-30-06-22.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# Found image: R201_ch1_video_03_00-30-10-07.jpg in /home/yash/Desktop/project/new dataset/train1/Gallbladder
# ...
# Found image: aug_2560_R305_ch1_video_04_00-36-58-21.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2561_R305_ch1_video_04_00-38-07-02.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2562_R305_ch1_video_04_00-41-19-16.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2563_R305_ch1_video_04_00-39-13-02.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2564_R305_ch1_video_04_00-39-13-02.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2565_R084_ch1_video_01_00-09-31-12.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2566_R010_ch1_video_03_00-25-18-05.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2567_R117_ch1_video_03_00-33-19-23.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2568_R117_ch1_video_03_00-33-19-23.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2569_R305_ch1_video_04_00-36-35-15.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2570_R305_ch1_video_04_00-24-40-14.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2571_R305_ch1_video_04_00-41-19-16.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2572_R305_ch1_video_04_00-39-15-20.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2573_R305_ch1_video_04_00-36-58-21.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2574_R305_ch1_video_04_00-39-13-02.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2575_R305_ch1_video_04_00-41-29-28.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2576_R007_ch1_video_04_00-14-38-12.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2577_R010_ch1_video_03_00-25-18-05.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2578_R203_ch1_video_03_00-25-00-06.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2579_R117_ch1_video_03_00-26-41-24.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2580_R305_ch1_video_04_00-38-07-02.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2581_R305_ch1_video_04_00-38-37-02.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2582_R305_ch1_video_04_00-38-07-02.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2583_R209_ch1_video_03_01-13-10-00.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2584_R305_ch1_video_04_00-38-07-02.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2585_R305_ch1_video_04_00-38-37-02.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2586_R305_ch1_video_04_00-38-07-02.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2587_R305_ch1_video_04_00-41-29-28.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2588_R305_ch1_video_04_00-36-35-15.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2589_R305_ch1_video_04_00-38-07-02.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2590_R209_ch1_video_03_01-13-10-00.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2591_R010_ch1_video_03_00-25-18-05.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2592_R305_ch1_video_04_00-38-07-02.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2593_R305_ch1_video_04_00-36-58-21.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2594_R305_ch1_video_04_00-41-29-28.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2595_R305_ch1_video_04_00-24-40-14.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2596_R305_ch1_video_04_00-41-14-13.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2597_R084_ch1_video_01_00-09-31-12.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2598_R302_ch1_video_04_00-27-10-07.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2599_R117_ch1_video_03_00-33-19-23.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2600_R302_ch1_video_04_00-27-10-07.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2601_R305_ch1_video_04_00-36-58-21.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2602_R117_ch1_video_03_00-33-19-23.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2603_R305_ch1_video_04_00-38-29-27.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2604_R117_ch1_video_03_00-33-19-23.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2605_R007_ch1_video_04_00-14-38-12.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2606_R305_ch1_video_04_00-39-13-02.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2607_R305_ch1_video_04_00-36-35-15.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2608_R305_ch1_video_04_00-41-24-23.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2609_R305_ch1_video_04_00-41-24-23.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2610_R305_ch1_video_04_00-41-19-16.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2611_R117_ch1_video_03_00-26-41-24.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2612_R305_ch1_video_04_00-38-29-27.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2613_R305_ch1_video_04_00-41-24-23.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2614_R007_ch1_video_04_00-14-38-12.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2615_R305_ch1_video_04_00-38-07-02.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2616_R117_ch1_video_03_00-26-41-24.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2617_R305_ch1_video_04_00-41-29-28.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2618_R117_ch1_video_03_00-26-41-24.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2619_R305_ch1_video_04_00-39-15-20.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2620_R305_ch1_video_04_00-38-29-27.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2621_R305_ch1_video_04_00-41-24-23.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2622_R117_ch1_video_03_00-33-19-23.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2623_R305_ch1_video_04_00-41-29-28.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2624_R084_ch1_video_01_00-09-31-12.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2625_R305_ch1_video_04_00-41-24-23.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2626_R305_ch1_video_04_00-38-07-02.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2627_R305_ch1_video_04_00-36-35-15.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2628_R305_ch1_video_04_00-41-19-16.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2629_R084_ch1_video_01_00-09-31-12.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2630_R305_ch1_video_04_00-41-29-28.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2631_R305_ch1_video_04_00-24-40-14.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2632_R302_ch1_video_04_00-27-10-07.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2633_R203_ch1_video_03_00-25-00-06.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2634_R007_ch1_video_04_00-14-38-12.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2635_R305_ch1_video_04_00-41-19-16.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2636_R302_ch1_video_04_00-27-10-07.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2637_R305_ch1_video_04_00-38-07-02.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2638_R084_ch1_video_01_00-09-31-12.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2639_R305_ch1_video_04_00-41-29-28.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2640_R305_ch1_video_04_00-39-13-02.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2641_R305_ch1_video_04_00-39-15-20.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2642_R305_ch1_video_04_00-39-13-02.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2643_R305_ch1_video_04_00-36-35-15.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2644_R305_ch1_video_04_00-39-13-02.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2645_R305_ch1_video_04_00-38-07-02.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2646_R305_ch1_video_04_00-41-29-28.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2647_R084_ch1_video_01_00-09-31-12.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2648_R305_ch1_video_04_00-36-35-15.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2649_R305_ch1_video_04_00-36-35-15.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2650_R203_ch1_video_03_00-25-00-06.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2651_R305_ch1_video_04_00-36-58-21.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2652_R305_ch1_video_04_00-36-58-21.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2653_R305_ch1_video_04_00-41-19-16.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2654_R007_ch1_video_04_00-14-38-12.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2655_R305_ch1_video_04_00-41-14-13.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2656_R305_ch1_video_04_00-41-24-23.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2657_R117_ch1_video_03_00-26-41-24.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2658_R305_ch1_video_04_00-38-07-02.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2659_R209_ch1_video_03_01-13-10-00.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2660_R305_ch1_video_04_00-41-24-23.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2661_R010_ch1_video_03_00-25-18-05.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2662_R209_ch1_video_03_01-13-10-00.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2663_R305_ch1_video_04_00-41-14-13.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2664_R305_ch1_video_04_00-36-35-15.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2665_R209_ch1_video_03_01-13-10-00.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2666_R010_ch1_video_03_00-25-18-05.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2667_R305_ch1_video_04_00-41-19-16.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2668_R305_ch1_video_04_00-24-40-14.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2669_R305_ch1_video_04_00-38-37-02.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2670_R305_ch1_video_04_00-39-15-20.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2671_R305_ch1_video_04_00-24-40-14.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2672_R305_ch1_video_04_00-38-37-02.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2673_R305_ch1_video_04_00-38-07-02.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2674_R203_ch1_video_03_00-25-00-06.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2675_R302_ch1_video_04_00-27-10-07.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2676_R117_ch1_video_03_00-33-19-23.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2677_R305_ch1_video_04_00-24-40-14.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2678_R305_ch1_video_04_00-39-15-20.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2679_R305_ch1_video_04_00-41-24-23.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2680_R305_ch1_video_04_00-36-35-15.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2681_R305_ch1_video_04_00-39-13-02.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2682_R305_ch1_video_04_00-38-07-02.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2683_R305_ch1_video_04_00-39-13-02.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2684_R305_ch1_video_04_00-41-14-13.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2685_R305_ch1_video_04_00-39-15-20.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2686_R305_ch1_video_04_00-39-13-02.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2687_R305_ch1_video_04_00-41-29-28.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2688_R302_ch1_video_04_00-27-10-07.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2689_R305_ch1_video_04_00-39-13-02.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2690_R305_ch1_video_04_00-41-19-16.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2691_R305_ch1_video_04_00-41-24-23.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2692_R305_ch1_video_04_00-41-24-23.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2693_R305_ch1_video_04_00-39-13-02.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2694_R305_ch1_video_04_00-38-29-27.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2695_R305_ch1_video_04_00-24-40-14.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2696_R305_ch1_video_04_00-24-40-14.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2697_R084_ch1_video_01_00-09-31-12.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2698_R305_ch1_video_04_00-24-40-14.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
# Found image: aug_2699_R305_ch1_video_04_00-41-24-23.jpg in /home/yash/Desktop/project/new dataset/train1/Spleen
#
# ✅ All images (including duplicates) saved to: /home/yash/Desktop/project/new dataset/ft1
# ✅ Merged CSV written to: /home/yash/Desktop/project/new dataset/ft1/main_labels.csv
# 📝 Log file saved to: /home/yash/Desktop/project/new dataset/ft1/merge_log.txt

# %% [markdown]
# script to downsample images

# %%
import os
import random
import pandas as pd

# Paths
IMAGE_FOLDER = "/home/yash/Desktop/project/new dataset/train1/Pancreas"  # Update with the path to your image folder
CSV_PATH = "/home/yash/Desktop/project/new dataset/train1/Pancreas/new_train1.csv"  # Update with the path to your CSV file
OUTPUT_CSV_PATH = "/home/yash/Desktop/project/new dataset/train1/Pancreas/new_train2.csv"  # Path to save the updated CSV
NUM_IMAGES_TO_DELETE = 1000  # Number of images to delete

# Read the CSV file
df = pd.read_csv(CSV_PATH)

# List all image files in the folder
all_images = [f for f in os.listdir(IMAGE_FOLDER) if os.path.isfile(os.path.join(IMAGE_FOLDER, f))]

# Filter only augmented images (assuming they contain 'aug' in the filename)
augmented_images = [img for img in all_images if 'aug' in img]

# Check if there are enough augmented images
if len(augmented_images) < NUM_IMAGES_TO_DELETE:
    print(f"⚠️ There are only {len(augmented_images)} augmented images. Deleting all of them.")
    NUM_IMAGES_TO_DELETE = len(augmented_images)

# Randomly select images to delete
images_to_delete = random.sample(augmented_images, NUM_IMAGES_TO_DELETE)

# Remove selected images from the folder
for image in images_to_delete:
    image_path = os.path.join(IMAGE_FOLDER, image)
    if os.path.exists(image_path):
        os.remove(image_path)
        print(f"✅ Deleted: {image}")

# Update the CSV file by removing the rows for the deleted images
df = df[~df['filename'].isin(images_to_delete)]

# Save the updated CSV
df.to_csv(OUTPUT_CSV_PATH, index=False)
print(f"✅ Updated CSV saved to: {OUTPUT_CSV_PATH}")

print(f"✅ {NUM_IMAGES_TO_DELETE} augmented images deleted and CSV updated.")
# Out:
# ✅ Deleted: aug_2252_R002_ch1_video_03_00-40-41-21.jpg
# ✅ Deleted: aug_2392_R001_ch1_video_03_00-52-00-17.jpg
# ✅ Deleted: aug_1170_R209_ch1_video_01_00-57-20-00.jpg
# ✅ Deleted: aug_1666_R206_ch1_video_03_00-03-09-28.jpg
# ✅ Deleted: aug_1176_R084_ch1_video_03_00-05-26-12.jpg
# ✅ Deleted: aug_1515_R005_ch1_video_01_00-49-32-21.jpg
# ✅ Deleted: aug_2153_R100_ch1_video_01_00-49-23-05.jpg
# ✅ Deleted: aug_2073_R301_ch1_video_04_00-15-57-12.jpg
# ✅ Deleted: aug_1759_R014_ch1_video_03_00-23-24-04.jpg
# ✅ Deleted: aug_1245_R010_ch1_video_01_00-40-39-20.jpg
# ✅ Deleted: aug_2023_R002_ch1_video_01_00-41-27-13.jpg
# ✅ Deleted: aug_727_R048_ch1_video_02_00-11-41-16.jpg
# ✅ Deleted: aug_729_R002_ch1_video_03_00-40-52-30.jpg
# ✅ Deleted: aug_1917_R014_ch1_video_03_01-03-19-26.jpg
# ✅ Deleted: aug_1010_R305_ch1_video_04_00-01-14-12.jpg
# ✅ Deleted: aug_1643_R301_ch1_video_04_00-36-59-13.jpg
# ✅ Deleted: aug_1002_R205_ch1_video_05_00-00-02-20.jpg
# ✅ Deleted: aug_972_R117_ch1_video_03_00-35-47-01.jpg
# ✅ Deleted: aug_843_R015_ch1_video_03_00-18-54-08.jpg
# ✅ Deleted: aug_728_R305_ch1_video_04_00-01-00-08.jpg
# ✅ Deleted: aug_365_R313_ch1_video_03_00-42-42-18.jpg
# ✅ Deleted: aug_1050_R305_ch1_video_04_00-41-14-13.jpg
# ✅ Deleted: aug_228_R305_ch1_video_04_00-29-37-01.jpg
# ✅ Deleted: aug_851_R019_ch1_video_05_00-11-19-07.jpg
# ✅ Deleted: aug_2402_R084_ch1_video_03_00-02-28-14.jpg
# ✅ Deleted: aug_1996_R015_ch1_video_03_00-37-03-25.jpg
# ✅ Deleted: aug_1192_R305_ch1_video_04_00-26-16-21.jpg
# ✅ Deleted: aug_396_R084_ch1_video_01_01-15-49-26.jpg
# ✅ Deleted: aug_475_R210_ch2_video_04_00-08-36-07.jpg
# ✅ Deleted: aug_2370_R201_ch1_video_03_00-37-16-24.jpg
# ✅ Deleted: aug_1360_R014_ch1_video_03_01-14-24-10.jpg
# ✅ Deleted: aug_668_R094_ch1_video_01_01-14-37-07.jpg
# ✅ Deleted: aug_307_R305_ch1_video_01_01-14-43-02.jpg
# ✅ Deleted: aug_1819_R201_ch1_video_03_00-07-43-11.jpg
# ✅ Deleted: aug_1309_R019_ch1_video_05_00-11-19-07.jpg
# ✅ Deleted: aug_193_R201_ch1_video_03_00-24-59-28.jpg
# ✅ Deleted: aug_1120_R094_ch1_video_01_01-10-37-17.jpg
# ✅ Deleted: aug_1310_R094_ch1_video_01_01-10-37-17.jpg
# ✅ Deleted: aug_1321_R203_ch1_video_03_00-11-03-14.jpg
# ✅ Deleted: aug_980_R001_ch1_video_03_00-57-53-26.jpg
# ✅ Deleted: aug_940_R001_ch1_video_03_01-11-51-25.jpg
# ✅ Deleted: aug_623_R302_ch1_video_04_00-27-10-07.jpg
# ✅ Deleted: aug_48_R074_ch1_video_01_00-53-15-24.jpg
# ✅ Deleted: aug_2204_R005_ch1_video_03_00-10-46-28.jpg
# ✅ Deleted: aug_238_R015_ch1_video_03_00-36-50-25.jpg
# ✅ Deleted: aug_1326_R014_ch1_video_03_01-03-19-26.jpg
# ✅ Deleted: aug_2281_R007_ch1_video_01_00-47-24-03.jpg
# ✅ Deleted: aug_2146_R056_ch1_video_01_00-39-18-04.jpg
# ✅ Deleted: aug_114_R084_ch1_video_03_00-59-53-19.jpg
# ✅ Deleted: aug_892_R048_ch1_video_02_00-41-03-29.jpg
# ✅ Deleted: aug_61_R301_ch1_video_04_00-18-50-16.jpg
# ✅ Deleted: aug_1606_R094_ch1_video_03_00-00-45-19.jpg
# ✅ Deleted: aug_373_R203_ch1_video_03_00-28-32-19.jpg
# ✅ Deleted: aug_795_R305_ch1_video_01_01-00-34-25.jpg
# ✅ Deleted: aug_2059_R015_ch1_video_03_00-37-34-26.jpg
# ✅ Deleted: aug_1012_R117_ch1_video_03_00-23-58-01.jpg
# ✅ Deleted: aug_2246_R094_ch1_video_03_00-01-03-19.jpg
# ✅ Deleted: aug_886_R205_ch1_video_03_00-28-36-14.jpg
# ✅ Deleted: aug_2081_R205_ch1_video_05_00-12-56-27.jpg
# ✅ Deleted: aug_895_R209_ch1_video_03_01-07-08-23.jpg
# ✅ Deleted: aug_1927_R117_ch1_video_03_00-35-47-01.jpg
# ✅ Deleted: aug_1344_R056_ch1_video_01_00-39-00-26.jpg
# ✅ Deleted: aug_2314_R209_ch1_video_03_01-10-43-15.jpg
# ✅ Deleted: aug_1349_R203_ch1_video_03_00-30-12-28.jpg
# ✅ Deleted: aug_2309_R002_ch1_video_01_00-59-35-06.jpg
# ✅ Deleted: aug_520_R210_ch2_video_04_00-06-00-02.jpg
# ✅ Deleted: aug_2250_R117_ch1_video_01_00-52-06-12.jpg
# ✅ Deleted: aug_1926_R084_ch1_video_03_00-41-35-16.jpg
# ✅ Deleted: aug_2109_R015_ch1_video_01_00-57-06-15.jpg
# ✅ Deleted: aug_1705_R002_ch1_video_01_00-49-11-28.jpg
# ✅ Deleted: aug_2276_R005_ch1_video_01_00-24-56-18.jpg
# ✅ Deleted: aug_1169_R002_ch1_video_03_00-40-52-30.jpg
# ✅ Deleted: aug_2189_R304_ch1_video_03_00-48-17-07.jpg
# ✅ Deleted: aug_138_R305_ch1_video_04_00-41-24-23.jpg
# ✅ Deleted: aug_859_R304_ch1_video_03_00-48-56-22.jpg
# ✅ Deleted: aug_1374_R002_ch1_video_01_01-00-13-01.jpg
# ✅ Deleted: aug_2123_R210_ch2_video_04_00-16-22-19.jpg
# ✅ Deleted: aug_882_R074_ch1_video_01_00-52-54-22.jpg
# ✅ Deleted: aug_600_R074_ch1_video_01_00-53-15-24.jpg
# ✅ Deleted: aug_50_R014_ch1_video_03_01-03-43-17.jpg
# ✅ Deleted: aug_2068_R084_ch1_video_03_00-57-31-04.jpg
# ✅ Deleted: aug_2254_R015_ch1_video_01_00-57-06-15.jpg
# ✅ Deleted: aug_131_R002_ch1_video_03_00-20-26-17.jpg
# ✅ Deleted: aug_2112_R201_ch1_video_03_00-41-44-26.jpg
# ✅ Deleted: aug_2461_R305_ch1_video_04_00-00-01-20.jpg
# ✅ Deleted: aug_2278_R203_ch1_video_03_00-26-45-09.jpg
# ✅ Deleted: aug_1786_R204_ch1_video_02_00-39-14-20.jpg
# ✅ Deleted: aug_2046_R048_ch1_video_02_00-13-46-15.jpg
# ✅ Deleted: aug_1897_R313_ch1_video_03_00-42-36-13.jpg
# ✅ Deleted: aug_2330_R117_ch1_video_01_00-52-06-12.jpg
# ✅ Deleted: aug_1336_R002_ch1_video_01_01-00-13-01.jpg
# ✅ Deleted: aug_123_R201_ch1_video_03_00-37-31-24.jpg
# ✅ Deleted: aug_787_R301_ch1_video_04_00-20-11-13.jpg
# ✅ Deleted: aug_1829_R313_ch1_video_03_00-42-36-13.jpg
# ✅ Deleted: aug_210_R002_ch1_video_03_00-40-46-13.jpg
# ✅ Deleted: aug_987_R305_ch1_video_04_00-36-35-15.jpg
# ✅ Deleted: aug_20_R117_ch1_video_03_00-35-36-02.jpg
# ✅ Deleted: aug_1301_R001_ch1_video_01_00-57-36-10.jpg
# ✅ Deleted: aug_247_R002_ch1_video_01_00-49-11-28.jpg
# ✅ Deleted: aug_461_R305_ch1_video_04_00-36-35-15.jpg
# ✅ Deleted: aug_33_R019_ch1_video_01_00-59-09-10.jpg
# ✅ Deleted: aug_1788_R010_ch1_video_01_00-32-07-14.jpg
# ✅ Deleted: aug_25_R076_ch1_video_03_00-18-53-06.jpg
# ✅ Deleted: aug_2077_R015_ch1_video_03_00-37-42-16.jpg
# ✅ Deleted: aug_731_R207_ch1_video_03_00-34-17-08.jpg
# ✅ Deleted: aug_1136_R001_ch1_video_01_00-57-14-23.jpg
# ✅ Deleted: aug_2052_R084_ch1_video_03_00-59-53-19.jpg
# ✅ Deleted: aug_547_R117_ch1_video_03_00-35-44-02.jpg
# ✅ Deleted: aug_2328_R313_ch1_video_03_00-20-54-07.jpg
# ✅ Deleted: aug_1695_R302_ch1_video_04_00-28-16-18.jpg
# ✅ Deleted: aug_1078_R001_ch1_video_01_00-57-58-10.jpg
# ✅ Deleted: aug_1592_R002_ch1_video_01_00-58-54-01.jpg
# ✅ Deleted: aug_609_R076_ch1_video_01_00-45-38-05.jpg
# ✅ Deleted: aug_469_R204_ch1_video_02_00-39-14-20.jpg
# ✅ Deleted: aug_1187_R002_ch1_video_03_00-40-26-12.jpg
# ✅ Deleted: aug_1172_R010_ch1_video_01_00-40-34-20.jpg
# ✅ Deleted: aug_127_R010_ch1_video_01_00-40-39-20.jpg
# ✅ Deleted: aug_1520_R015_ch1_video_01_00-57-31-08.jpg
# ✅ Deleted: aug_1495_R305_ch1_video_04_00-38-07-02.jpg
# ✅ Deleted: aug_1750_R117_ch1_video_03_00-17-35-21.jpg
# ✅ Deleted: aug_744_R084_ch1_video_01_01-15-49-26.jpg
# ✅ Deleted: aug_2376_R203_ch1_video_03_00-30-51-18.jpg
# ✅ Deleted: aug_23_R201_ch1_video_03_00-41-41-04.jpg
# ✅ Deleted: aug_619_R117_ch1_video_01_00-52-05-19.jpg
# ✅ Deleted: aug_2161_R100_ch1_video_01_01-14-57-07.jpg
# ✅ Deleted: aug_1094_R313_ch1_video_03_00-42-54-26.jpg
# ✅ Deleted: aug_344_R002_ch1_video_03_00-29-50-01.jpg
# ✅ Deleted: aug_950_R313_ch1_video_03_00-43-22-06.jpg
# ✅ Deleted: aug_834_R001_ch1_video_03_00-55-04-15.jpg
# ✅ Deleted: aug_2159_R014_ch1_video_03_01-03-19-26.jpg
# ✅ Deleted: aug_1167_R201_ch1_video_03_00-37-16-24.jpg
# ✅ Deleted: aug_990_R204_ch1_video_02_00-39-16-13.jpg
# ✅ Deleted: aug_2249_R019_ch1_video_05_00-11-02-05.jpg
# ✅ Deleted: aug_2056_R001_ch1_video_03_01-11-57-19.jpg
# ✅ Deleted: aug_2339_R010_ch1_video_01_00-40-39-20.jpg
# ✅ Deleted: aug_153_R117_ch1_video_03_00-35-39-01.jpg
# ✅ Deleted: aug_686_R014_ch1_video_03_01-03-37-17.jpg
# ✅ Deleted: aug_2279_R014_ch1_video_03_01-03-37-17.jpg
# ✅ Deleted: aug_374_R301_ch1_video_04_00-18-50-16.jpg
# ✅ Deleted: aug_2414_R305_ch1_video_04_00-26-16-21.jpg
# ✅ Deleted: aug_1195_R015_ch1_video_03_00-37-43-24.jpg
# ✅ Deleted: aug_1710_R084_ch1_video_03_00-05-26-12.jpg
# ✅ Deleted: aug_1414_R305_ch1_video_04_00-38-29-27.jpg
# ✅ Deleted: aug_759_R015_ch1_video_03_00-37-00-25.jpg
# ✅ Deleted: aug_2338_R305_ch1_video_04_00-00-01-20.jpg
# ✅ Deleted: aug_1523_R313_ch1_video_03_00-42-31-11.jpg
# ✅ Deleted: aug_1699_R201_ch1_video_03_00-39-32-00.jpg
# ✅ Deleted: aug_290_R201_ch1_video_03_00-24-59-28.jpg
# ✅ Deleted: aug_1526_R002_ch1_video_03_00-40-31-13.jpg
# ✅ Deleted: aug_1522_R001_ch1_video_01_01-12-47-27.jpg
# ✅ Deleted: aug_2253_R302_ch1_video_04_00-27-42-03.jpg
# ✅ Deleted: aug_2477_R203_ch1_video_03_00-26-51-09.jpg
# ✅ Deleted: aug_32_R002_ch1_video_03_00-40-31-13.jpg
# ✅ Deleted: aug_1082_R084_ch1_video_03_00-57-44-25.jpg
# ✅ Deleted: aug_1551_R206_ch1_video_03_00-27-01-09.jpg
# ✅ Deleted: aug_848_R005_ch1_video_03_00-19-00-02.jpg
# ✅ Deleted: aug_805_R010_ch1_video_01_00-40-34-20.jpg
# ✅ Deleted: aug_2493_R203_ch1_video_03_00-26-43-02.jpg
# ✅ Deleted: aug_2364_R209_ch1_video_03_01-14-32-00.jpg
# ✅ Deleted: aug_203_R201_ch1_video_03_00-39-32-00.jpg
# ✅ Deleted: aug_119_R204_ch1_video_02_00-39-19-16.jpg
# ✅ Deleted: aug_1855_R001_ch1_video_01_00-57-58-10.jpg
# ✅ Deleted: aug_1874_R301_ch1_video_01_00-50-16-07.jpg
# ✅ Deleted: aug_1993_R203_ch1_video_03_00-14-49-12.jpg
# ✅ Deleted: aug_1151_R201_ch1_video_03_00-37-39-20.jpg
# ✅ Deleted: aug_1884_R074_ch1_video_01_00-52-54-24.jpg
# ✅ Deleted: aug_2160_R302_ch1_video_04_00-28-34-18.jpg
# ✅ Deleted: aug_2318_R301_ch1_video_04_00-36-59-13.jpg
# ✅ Deleted: aug_1450_R015_ch1_video_03_00-37-42-16.jpg
# ✅ Deleted: aug_525_R206_ch1_video_03_00-03-09-28.jpg
# ✅ Deleted: aug_587_R305_ch1_video_04_00-38-07-02.jpg
# ✅ Deleted: aug_246_R305_ch1_video_04_00-00-01-20.jpg
# ✅ Deleted: aug_2262_R001_ch1_video_03_01-11-51-25.jpg
# ✅ Deleted: aug_224_R305_ch1_video_01_01-14-43-02.jpg
# ✅ Deleted: aug_808_R305_ch1_video_04_00-36-35-15.jpg
# ✅ Deleted: aug_1319_R010_ch1_video_01_00-38-04-25.jpg
# ✅ Deleted: aug_384_R313_ch1_video_01_00-26-46-17.jpg
# ✅ Deleted: aug_2130_R204_ch1_video_02_00-39-09-15.jpg
# ✅ Deleted: aug_1079_R301_ch1_video_04_00-17-18-20.jpg
# ✅ Deleted: aug_734_R204_ch1_video_01_00-56-53-09.jpg
# ✅ Deleted: aug_159_R014_ch1_video_03_00-59-31-16.jpg
# ✅ Deleted: aug_1760_R204_ch1_video_01_00-56-53-09.jpg
# ✅ Deleted: aug_2459_R117_ch1_video_03_00-35-36-01.jpg
# ✅ Deleted: aug_79_R301_ch1_video_01_00-57-52-00.jpg
# ✅ Deleted: aug_176_R203_ch1_video_03_00-28-32-19.jpg
# ✅ Deleted: aug_2313_R015_ch1_video_03_00-36-55-25.jpg
# ✅ Deleted: aug_2101_R210_ch2_video_04_00-14-52-02.jpg
# ✅ Deleted: aug_505_R305_ch1_video_04_00-41-29-28.jpg
# ✅ Deleted: aug_34_R205_ch1_video_03_00-31-59-18.jpg
# ✅ Deleted: aug_959_R305_ch1_video_01_01-00-34-25.jpg
# ✅ Deleted: aug_733_R313_ch1_video_03_00-42-40-01.jpg
# ✅ Deleted: aug_1358_R302_ch1_video_04_00-28-16-18.jpg
# ✅ Deleted: aug_1557_R203_ch1_video_03_00-25-00-06.jpg
# ✅ Deleted: aug_824_R100_ch1_video_01_00-49-23-05.jpg
# ✅ Deleted: aug_669_R313_ch1_video_03_00-43-17-02.jpg
# ✅ Deleted: aug_1039_R201_ch1_video_03_00-39-53-10.jpg
# ✅ Deleted: aug_407_R117_ch1_video_03_00-26-41-24.jpg
# ✅ Deleted: aug_1995_R014_ch1_video_03_01-14-29-10.jpg
# ✅ Deleted: aug_506_R005_ch1_video_03_00-19-00-02.jpg
# ✅ Deleted: aug_968_R202_ch1_video_05_00-34-13-09.jpg
# ✅ Deleted: aug_617_R210_ch2_video_04_00-10-12-05.jpg
# ✅ Deleted: aug_1636_R301_ch1_video_04_00-36-59-13.jpg
# ✅ Deleted: aug_1352_R019_ch1_video_01_00-59-09-10.jpg
# ✅ Deleted: aug_1922_R001_ch1_video_03_01-13-02-01.jpg
# ✅ Deleted: aug_1241_R015_ch1_video_03_00-33-49-22.jpg
# ✅ Deleted: aug_1041_R117_ch1_video_03_00-35-58-04.jpg
# ✅ Deleted: aug_1422_R206_ch1_video_03_00-02-28-16.jpg
# ✅ Deleted: aug_2019_R014_ch1_video_03_00-23-12-03.jpg
# ✅ Deleted: aug_680_R002_ch1_video_01_01-00-13-01.jpg
# ✅ Deleted: aug_780_R209_ch1_video_03_01-10-38-15.jpg
# ✅ Deleted: aug_1473_R001_ch1_video_03_01-00-36-26.jpg
# ✅ Deleted: aug_981_R001_ch1_video_01_01-12-47-27.jpg
# ✅ Deleted: aug_858_R015_ch1_video_01_00-56-51-13.jpg
# ✅ Deleted: aug_2095_R204_ch1_video_02_00-40-10-08.jpg
# ✅ Deleted: aug_1431_R014_ch1_video_03_00-55-29-16.jpg
# ✅ Deleted: aug_1669_R202_ch1_video_05_00-34-13-09.jpg
# ✅ Deleted: aug_581_R002_ch1_video_01_00-58-54-01.jpg
# ✅ Deleted: aug_1124_R313_ch1_video_03_00-42-31-06.jpg
# ✅ Deleted: aug_1688_R313_ch1_video_03_00-43-26-06.jpg
# ✅ Deleted: aug_821_R301_ch1_video_04_00-37-01-22.jpg
# ✅ Deleted: aug_811_R005_ch1_video_01_00-24-56-18.jpg
# ✅ Deleted: aug_1000_R313_ch1_video_03_00-42-40-01.jpg
# ✅ Deleted: aug_80_R117_ch1_video_03_00-17-35-21.jpg
# ✅ Deleted: aug_1737_R084_ch1_video_03_00-36-32-19.jpg
# ✅ Deleted: aug_897_R001_ch1_video_01_01-10-53-01.jpg
# ✅ Deleted: aug_2120_R207_ch1_video_03_00-34-17-08.jpg
# ✅ Deleted: aug_2358_R117_ch1_video_03_00-35-44-02.jpg
# ✅ Deleted: aug_1260_R313_ch1_video_03_00-42-36-13.jpg
# ✅ Deleted: aug_1311_R301_ch1_video_04_00-17-18-20.jpg
# ✅ Deleted: aug_1240_R203_ch1_video_03_00-26-43-02.jpg
# ✅ Deleted: aug_1252_R094_ch1_video_01_01-14-37-07.jpg
# ✅ Deleted: aug_78_R209_ch1_video_03_01-10-35-15.jpg
# ✅ Deleted: aug_2291_R084_ch1_video_03_00-36-32-19.jpg
# ✅ Deleted: aug_2391_R210_ch1_video_01_00-53-01-16.jpg
# ✅ Deleted: aug_841_R010_ch1_video_01_00-40-39-20.jpg
# ✅ Deleted: aug_2176_R014_ch1_video_03_00-24-31-18.jpg
# ✅ Deleted: aug_1648_R301_ch1_video_01_00-50-16-07.jpg
# ✅ Deleted: aug_871_R002_ch1_video_01_01-06-56-20.jpg
# ✅ Deleted: aug_861_R019_ch1_video_05_00-11-02-05.jpg
# ✅ Deleted: aug_1992_R015_ch1_video_01_00-40-06-07.jpg
# ✅ Deleted: aug_472_R094_ch1_video_03_00-00-45-19.jpg
# ✅ Deleted: aug_2458_R014_ch1_video_03_00-07-49-22.jpg
# ✅ Deleted: aug_352_R201_ch1_video_03_00-41-41-04.jpg
# ✅ Deleted: aug_417_R014_ch1_video_03_01-14-19-20.jpg
# ✅ Deleted: aug_910_R014_ch1_video_03_01-14-24-10.jpg
# ✅ Deleted: aug_2064_R201_ch1_video_03_00-41-41-04.jpg
# ✅ Deleted: aug_2380_R074_ch1_video_03_00-23-03-08.jpg
# ✅ Deleted: aug_1828_R005_ch1_video_01_00-24-56-18.jpg
# ✅ Deleted: aug_1005_R007_ch1_video_01_00-46-44-27.jpg
# ✅ Deleted: aug_870_R201_ch1_video_03_00-27-57-02.jpg
# ✅ Deleted: aug_426_R010_ch1_video_01_00-32-07-14.jpg
# ✅ Deleted: aug_195_R301_ch1_video_04_00-36-59-13.jpg
# ✅ Deleted: aug_1346_R001_ch1_video_01_00-57-36-10.jpg
# ✅ Deleted: aug_1314_R117_ch1_video_01_00-51-42-10.jpg
# ✅ Deleted: aug_1412_R305_ch1_video_04_00-41-24-23.jpg
# ✅ Deleted: aug_899_R302_ch1_video_04_00-27-42-03.jpg
# ✅ Deleted: aug_548_R301_ch1_video_01_00-44-24-00.jpg
# ✅ Deleted: aug_306_R001_ch1_video_03_00-52-00-17.jpg
# ✅ Deleted: aug_178_R084_ch1_video_03_00-59-39-16.jpg
# ✅ Deleted: aug_1063_R010_ch1_video_01_00-40-34-20.jpg
# ✅ Deleted: aug_1393_R302_ch1_video_04_00-28-34-18.jpg
# ✅ Deleted: aug_1683_R014_ch1_video_03_00-23-42-05.jpg
# ✅ Deleted: aug_1880_R015_ch1_video_03_00-37-03-25.jpg
# ✅ Deleted: aug_2145_R002_ch1_video_03_00-40-26-12.jpg
# ✅ Deleted: aug_400_R001_ch1_video_03_01-11-46-17.jpg
# ✅ Deleted: aug_1300_R302_ch1_video_04_00-27-42-03.jpg
# ✅ Deleted: aug_2199_R210_ch1_video_01_00-52-43-16.jpg
# ✅ Deleted: aug_2033_R002_ch1_video_03_00-41-02-20.jpg
# ✅ Deleted: aug_1259_R201_ch1_video_03_00-27-57-02.jpg
# ✅ Deleted: aug_1810_R001_ch1_video_01_01-13-08-07.jpg
# ✅ Deleted: aug_937_R117_ch1_video_03_00-35-58-04.jpg
# ✅ Deleted: aug_1164_R002_ch1_video_01_00-59-35-06.jpg
# ✅ Deleted: aug_2154_R203_ch1_video_03_00-30-51-18.jpg
# ✅ Deleted: aug_754_R001_ch1_video_03_01-11-44-17.jpg
# ✅ Deleted: aug_421_R019_ch1_video_05_00-11-27-28.jpg
# ✅ Deleted: aug_2274_R005_ch1_video_01_00-49-32-21.jpg
# ✅ Deleted: aug_1117_R305_ch1_video_04_00-41-14-13.jpg
# ✅ Deleted: aug_761_R002_ch1_video_03_00-25-08-15.jpg
# ✅ Deleted: aug_14_R094_ch1_video_03_00-00-37-29.jpg
# ✅ Deleted: aug_1284_R117_ch1_video_03_00-35-36-01.jpg
# ✅ Deleted: aug_1411_R002_ch1_video_03_00-29-50-01.jpg
# ✅ Deleted: aug_1943_R019_ch1_video_05_00-11-19-07.jpg
# ✅ Deleted: aug_1304_R203_ch1_video_03_00-26-43-02.jpg
# ✅ Deleted: aug_490_R014_ch1_video_03_00-07-49-22.jpg
# ✅ Deleted: aug_725_R205_ch1_video_03_01-16-32-22.jpg
# ✅ Deleted: aug_1354_R014_ch1_video_03_01-03-37-17.jpg
# ✅ Deleted: aug_1330_R005_ch1_video_01_00-43-10-14.jpg
# ✅ Deleted: aug_875_R014_ch1_video_03_00-07-49-22.jpg
# ✅ Deleted: aug_1734_R301_ch1_video_04_00-38-23-15.jpg
# ✅ Deleted: aug_957_R201_ch1_video_03_00-39-54-15.jpg
# ✅ Deleted: aug_1468_R005_ch1_video_03_00-19-30-11.jpg
# ✅ Deleted: aug_1915_R305_ch1_video_04_00-01-00-08.jpg
# ✅ Deleted: aug_2345_R100_ch1_video_01_00-49-23-05.jpg
# ✅ Deleted: aug_2454_R209_ch1_video_03_01-13-10-29.jpg
# ✅ Deleted: aug_104_R201_ch1_video_03_00-27-57-02.jpg
# ✅ Deleted: aug_1784_R203_ch1_video_03_00-16-53-06.jpg
# ✅ Deleted: aug_102_R301_ch1_video_04_00-15-24-02.jpg
# ✅ Deleted: aug_2031_R117_ch1_video_01_00-51-42-10.jpg
# ✅ Deleted: aug_245_R207_ch1_video_03_00-34-17-08.jpg
# ✅ Deleted: aug_310_R001_ch1_video_01_01-12-47-27.jpg
# ✅ Deleted: aug_1150_R001_ch1_video_03_00-52-00-17.jpg
# ✅ Deleted: aug_2093_R313_ch1_video_03_00-42-31-11.jpg
# ✅ Deleted: aug_206_R203_ch1_video_03_00-11-03-14.jpg
# ✅ Deleted: aug_1765_R301_ch1_video_04_00-38-20-22.jpg
# ✅ Deleted: aug_342_R117_ch1_video_01_00-54-18-00.jpg
# ✅ Deleted: aug_2232_R010_ch1_video_01_00-32-23-23.jpg
# ✅ Deleted: aug_6_R084_ch1_video_03_00-36-32-19.jpg
# ✅ Deleted: aug_1924_R301_ch1_video_04_00-38-23-15.jpg
# ✅ Deleted: aug_262_R204_ch1_video_02_00-39-16-13.jpg
# ✅ Deleted: aug_1594_R015_ch1_video_03_00-18-54-08.jpg
# ✅ Deleted: aug_2048_R014_ch1_video_03_01-03-37-17.jpg
# ✅ Deleted: aug_2322_R204_ch1_video_02_00-39-09-15.jpg
# ✅ Deleted: aug_457_R002_ch1_video_01_01-06-56-20.jpg
# ✅ Deleted: aug_381_R205_ch1_video_05_00-00-02-20.jpg
# ✅ Deleted: aug_1126_R015_ch1_video_03_00-31-22-20.jpg
# ✅ Deleted: aug_1619_R014_ch1_video_03_00-23-12-03.jpg
# ✅ Deleted: aug_2117_R002_ch1_video_01_00-41-54-26.jpg
# ✅ Deleted: aug_1003_R019_ch1_video_01_00-48-37-20.jpg
# ✅ Deleted: aug_601_R076_ch1_video_01_00-45-38-05.jpg
# ✅ Deleted: aug_1607_R005_ch1_video_03_00-19-10-11.jpg
# ✅ Deleted: aug_1123_R201_ch1_video_03_00-40-06-06.jpg
# ✅ Deleted: aug_1084_R002_ch1_video_01_00-41-38-11.jpg
# ✅ Deleted: aug_1474_R019_ch1_video_01_00-48-37-20.jpg
# ✅ Deleted: aug_807_R084_ch1_video_01_01-15-49-26.jpg
# ✅ Deleted: aug_765_R005_ch1_video_03_00-19-30-11.jpg
# ✅ Deleted: aug_1293_R010_ch1_video_03_00-26-39-20.jpg
# ✅ Deleted: aug_568_R001_ch1_video_01_01-10-53-01.jpg
# ✅ Deleted: aug_809_R204_ch1_video_02_00-39-45-13.jpg
# ✅ Deleted: aug_2022_R014_ch1_video_03_00-23-12-03.jpg
# ✅ Deleted: aug_1487_R203_ch1_video_03_00-26-51-09.jpg
# ✅ Deleted: aug_2369_R117_ch1_video_03_00-35-36-02.jpg
# ✅ Deleted: aug_2050_R015_ch1_video_03_00-39-16-06.jpg
# ✅ Deleted: aug_1944_R005_ch1_video_03_00-10-46-28.jpg
# ✅ Deleted: aug_12_R001_ch1_video_03_00-55-04-15.jpg
# ✅ Deleted: aug_1223_R001_ch1_video_03_01-11-46-17.jpg
# ✅ Deleted: aug_1981_R305_ch1_video_04_00-41-29-28.jpg
# ✅ Deleted: aug_299_R203_ch1_video_03_00-26-43-02.jpg
# ✅ Deleted: aug_2430_R302_ch1_video_04_00-28-16-18.jpg
# ✅ Deleted: aug_2035_R117_ch1_video_03_00-33-19-23.jpg
# ✅ Deleted: aug_1212_R206_ch1_video_01_01-15-30-05.jpg
# ✅ Deleted: aug_803_R301_ch1_video_04_00-38-20-22.jpg
# ✅ Deleted: aug_798_R094_ch1_video_03_00-00-45-19.jpg
# ✅ Deleted: aug_207_R203_ch1_video_03_00-26-51-09.jpg
# ✅ Deleted: aug_1747_R005_ch1_video_03_00-18-52-00.jpg
# ✅ Deleted: aug_615_R313_ch1_video_03_00-42-31-11.jpg
# ✅ Deleted: aug_745_R302_ch1_video_01_00-55-21-00.jpg
# ✅ Deleted: aug_1693_R084_ch1_video_03_00-58-33-12.jpg
# ✅ Deleted: aug_594_R205_ch1_video_05_00-12-56-27.jpg
# ✅ Deleted: aug_2034_R204_ch1_video_02_00-39-16-13.jpg
# ✅ Deleted: aug_212_R074_ch1_video_01_00-28-30-08.jpg
# ✅ Deleted: aug_1684_R014_ch1_video_03_00-23-42-05.jpg
# ✅ Deleted: aug_1639_R015_ch1_video_03_00-37-36-26.jpg
# ✅ Deleted: aug_1339_R203_ch1_video_03_00-11-03-14.jpg
# ✅ Deleted: aug_4_R305_ch1_video_04_00-26-16-17.jpg
# ✅ Deleted: aug_293_R204_ch1_video_01_00-56-53-09.jpg
# ✅ Deleted: aug_869_R001_ch1_video_01_01-11-51-01.jpg
# ✅ Deleted: aug_87_R015_ch1_video_03_00-38-09-02.jpg
# ✅ Deleted: aug_454_R010_ch1_video_03_00-25-18-07.jpg
# ✅ Deleted: aug_1677_R005_ch1_video_03_00-18-52-00.jpg
# ✅ Deleted: aug_1963_R313_ch1_video_03_00-43-26-06.jpg
# ✅ Deleted: aug_970_R084_ch1_video_03_00-36-35-12.jpg
# ✅ Deleted: aug_2324_R206_ch1_video_03_00-04-55-29.jpg
# ✅ Deleted: aug_1813_R001_ch1_video_03_01-12-03-10.jpg
# ✅ Deleted: aug_1068_R204_ch1_video_02_00-39-08-13.jpg
# ✅ Deleted: aug_2096_R117_ch1_video_03_00-26-41-24.jpg
# ✅ Deleted: aug_10_R002_ch1_video_01_00-59-35-06.jpg
# ✅ Deleted: aug_296_R100_ch1_video_01_00-48-54-07.jpg
# ✅ Deleted: aug_942_R015_ch1_video_03_00-36-54-27.jpg
# ✅ Deleted: aug_1549_R002_ch1_video_03_00-40-41-21.jpg
# ✅ Deleted: aug_1305_R203_ch1_video_03_00-26-51-09.jpg
# ✅ Deleted: aug_1902_R207_ch1_video_03_00-34-17-08.jpg
# ✅ Deleted: aug_233_R007_ch1_video_01_00-47-24-03.jpg
# ✅ Deleted: aug_359_R201_ch1_video_03_00-37-16-24.jpg
# ✅ Deleted: aug_931_R074_ch1_video_01_00-28-30-08.jpg
# ✅ Deleted: aug_528_R014_ch1_video_03_01-03-25-04.jpg
# ✅ Deleted: aug_1514_R002_ch1_video_03_00-27-41-24.jpg
# ✅ Deleted: aug_1405_R305_ch1_video_04_00-41-19-16.jpg
# ✅ Deleted: aug_1641_R001_ch1_video_03_01-11-57-19.jpg
# ✅ Deleted: aug_2094_R305_ch1_video_04_00-41-19-16.jpg
# ✅ Deleted: aug_2342_R084_ch1_video_03_00-59-23-00.jpg
# ✅ Deleted: aug_420_R201_ch1_video_03_00-41-53-13.jpg
# ✅ Deleted: aug_495_R002_ch1_video_03_00-41-17-13.jpg
# ✅ Deleted: aug_2053_R002_ch1_video_03_00-41-17-13.jpg
# ✅ Deleted: aug_91_R014_ch1_video_03_01-03-31-13.jpg
# ✅ Deleted: aug_523_R201_ch1_video_03_00-27-10-23.jpg
# ✅ Deleted: aug_2478_R301_ch1_video_04_00-20-10-01.jpg
# ✅ Deleted: aug_284_R203_ch1_video_03_00-26-51-09.jpg
# ✅ Deleted: aug_542_R305_ch1_video_04_00-41-24-23.jpg
# ✅ Deleted: aug_1758_R014_ch1_video_03_01-03-25-04.jpg
# ✅ Deleted: aug_220_R001_ch1_video_01_01-10-53-01.jpg
# ✅ Deleted: aug_2078_R014_ch1_video_03_00-23-24-04.jpg
# ✅ Deleted: aug_1185_R117_ch1_video_01_00-52-06-12.jpg
# ✅ Deleted: aug_1627_R201_ch1_video_03_00-27-19-22.jpg
# ✅ Deleted: aug_1763_R015_ch1_video_01_00-57-06-15.jpg
# ✅ Deleted: aug_1125_R002_ch1_video_03_00-41-17-13.jpg
# ✅ Deleted: aug_2213_R304_ch1_video_03_00-48-56-22.jpg
# ✅ Deleted: aug_44_R206_ch1_video_03_00-02-28-16.jpg
# ✅ Deleted: aug_956_R313_ch1_video_03_00-20-54-07.jpg
# ✅ Deleted: aug_113_R203_ch1_video_03_00-26-51-09.jpg
# ✅ Deleted: aug_387_R014_ch1_video_03_01-14-19-09.jpg
# ✅ Deleted: aug_1436_R203_ch1_video_03_00-16-53-06.jpg
# ✅ Deleted: aug_1338_R014_ch1_video_03_00-10-58-22.jpg
# ✅ Deleted: aug_919_R014_ch1_video_03_00-27-26-05.jpg
# ✅ Deleted: aug_779_R201_ch1_video_03_00-39-58-17.jpg
# ✅ Deleted: aug_399_R094_ch1_video_01_01-14-52-29.jpg
# ✅ Deleted: aug_2076_R206_ch1_video_01_00-29-04-19.jpg
# ✅ Deleted: aug_2383_R010_ch1_video_01_00-40-34-20.jpg
# ✅ Deleted: aug_1867_R301_ch1_video_01_00-50-16-07.jpg
# ✅ Deleted: aug_2143_R313_ch1_video_03_00-43-17-02.jpg
# ✅ Deleted: aug_1234_R019_ch1_video_03_00-33-26-10.jpg
# ✅ Deleted: aug_1390_R305_ch1_video_04_00-26-16-21.jpg
# ✅ Deleted: aug_2200_R001_ch1_video_01_01-10-53-01.jpg
# ✅ Deleted: aug_1499_R015_ch1_video_01_00-57-31-08.jpg
# ✅ Deleted: aug_1650_R206_ch1_video_01_00-29-04-19.jpg
# ✅ Deleted: aug_1687_R202_ch1_video_05_00-34-13-09.jpg
# ✅ Deleted: aug_2216_R001_ch1_video_03_01-04-03-09.jpg
# ✅ Deleted: aug_936_R117_ch1_video_01_00-51-26-10.jpg
# ✅ Deleted: aug_982_R001_ch1_video_01_00-57-36-10.jpg
# ✅ Deleted: aug_1142_R201_ch1_video_03_00-37-16-24.jpg
# ✅ Deleted: aug_1644_R304_ch1_video_03_00-41-03-02.jpg
# ✅ Deleted: aug_2222_R117_ch1_video_03_00-35-36-02.jpg
# ✅ Deleted: aug_1098_R002_ch1_video_03_00-40-26-12.jpg
# ✅ Deleted: aug_1020_R209_ch1_video_03_01-13-10-00.jpg
# ✅ Deleted: aug_2091_R094_ch1_video_01_01-14-52-29.jpg
# ✅ Deleted: aug_2212_R305_ch1_video_04_00-41-19-16.jpg
# ✅ Deleted: aug_1013_R002_ch1_video_03_00-40-47-29.jpg
# ✅ Deleted: aug_1333_R210_ch2_video_04_00-04-39-13.jpg
# ✅ Deleted: aug_272_R302_ch1_video_04_00-27-10-07.jpg
# ✅ Deleted: aug_2310_R094_ch1_video_03_00-00-10-05.jpg
# ✅ Deleted: aug_2315_R301_ch1_video_04_00-36-59-13.jpg
# ✅ Deleted: aug_275_R019_ch1_video_01_00-48-37-20.jpg
# ✅ Deleted: aug_558_R084_ch1_video_03_00-57-44-25.jpg
# ✅ Deleted: aug_1745_R010_ch1_video_03_00-25-18-07.jpg
# ✅ Deleted: aug_692_R014_ch1_video_03_00-59-31-16.jpg
# ✅ Deleted: aug_1105_R007_ch1_video_01_00-47-30-03.jpg
# ✅ Deleted: aug_701_R002_ch1_video_03_00-41-17-13.jpg
# ✅ Deleted: aug_2470_R005_ch1_video_03_00-18-54-00.jpg
# ✅ Deleted: aug_76_R117_ch1_video_03_00-35-56-02.jpg
# ✅ Deleted: aug_1615_R002_ch1_video_03_00-40-47-29.jpg
# ✅ Deleted: aug_1043_R209_ch1_video_03_01-11-47-13.jpg
# ✅ Deleted: aug_2225_R001_ch1_video_03_01-11-44-17.jpg
# ✅ Deleted: aug_318_R002_ch1_video_03_00-40-41-21.jpg
# ✅ Deleted: aug_2142_R056_ch1_video_01_00-39-00-26.jpg
# ✅ Deleted: aug_1878_R048_ch1_video_02_00-11-41-16.jpg
# ✅ Deleted: aug_708_R210_ch2_video_04_00-08-31-07.jpg
# ✅ Deleted: aug_2413_R076_ch1_video_03_00-33-26-00.jpg
# ✅ Deleted: aug_904_R084_ch1_video_03_00-05-26-12.jpg
# ✅ Deleted: aug_1283_R210_ch2_video_04_00-04-39-13.jpg
# ✅ Deleted: aug_2054_R205_ch1_video_03_00-28-36-14.jpg
# ✅ Deleted: aug_1184_R201_ch1_video_03_00-40-06-06.jpg
# ✅ Deleted: aug_663_R203_ch1_video_03_00-30-51-18.jpg
# ✅ Deleted: aug_684_R201_ch1_video_03_00-36-51-12.jpg
# ✅ Deleted: aug_1869_R007_ch1_video_01_00-46-44-27.jpg
# ✅ Deleted: aug_826_R019_ch1_video_05_00-11-27-28.jpg
# ✅ Deleted: aug_1860_R302_ch1_video_04_00-27-10-07.jpg
# ✅ Deleted: aug_2113_R056_ch1_video_01_00-39-45-20.jpg
# ✅ Deleted: aug_1443_R001_ch1_video_03_01-11-46-17.jpg
# ✅ Deleted: aug_583_R015_ch1_video_01_00-56-51-13.jpg
# ✅ Deleted: aug_1430_R117_ch1_video_03_00-36-04-00.jpg
# ✅ Deleted: aug_1409_R015_ch1_video_03_00-37-43-24.jpg
# ✅ Deleted: aug_1504_R304_ch1_video_03_00-48-17-07.jpg
# ✅ Deleted: aug_111_R203_ch1_video_03_00-26-43-02.jpg
# ✅ Deleted: aug_629_R014_ch1_video_03_00-23-12-03.jpg
# ✅ Deleted: aug_655_R001_ch1_video_03_01-11-46-17.jpg
# ✅ Deleted: aug_117_R210_ch2_video_04_00-08-31-07.jpg
# ✅ Deleted: aug_963_R204_ch1_video_02_00-39-16-13.jpg
# ✅ Deleted: aug_932_R301_ch1_video_04_00-17-18-20.jpg
# ✅ Deleted: aug_240_R014_ch1_video_03_00-23-42-05.jpg
# ✅ Deleted: aug_1830_R205_ch1_video_05_00-14-42-22.jpg
# ✅ Deleted: aug_1048_R015_ch1_video_03_00-39-16-06.jpg
# ✅ Deleted: aug_375_R206_ch1_video_01_00-29-04-19.jpg
# ✅ Deleted: aug_501_R074_ch1_video_01_00-28-30-08.jpg
# ✅ Deleted: aug_656_R100_ch1_video_01_01-14-57-07.jpg
# ✅ Deleted: aug_607_R117_ch1_video_03_00-34-13-14.jpg
# ✅ Deleted: aug_533_R002_ch1_video_03_00-40-52-30.jpg
# ✅ Deleted: aug_351_R002_ch1_video_01_00-59-35-06.jpg
# ✅ Deleted: aug_1570_R076_ch1_video_01_00-45-38-05.jpg
# ✅ Deleted: aug_1871_R304_ch1_video_03_00-48-01-14.jpg
# ✅ Deleted: aug_1980_R005_ch1_video_01_00-48-56-25.jpg
# ✅ Deleted: aug_175_R014_ch1_video_03_00-23-42-05.jpg
# ✅ Deleted: aug_1476_R007_ch1_video_04_00-14-38-12.jpg
# ✅ Deleted: aug_969_R005_ch1_video_03_00-05-34-14.jpg
# ✅ Deleted: aug_1265_R005_ch1_video_01_00-19-26-06.jpg
# ✅ Deleted: aug_1933_R301_ch1_video_04_00-15-24-02.jpg
# ✅ Deleted: aug_1599_R203_ch1_video_03_00-11-03-14.jpg
# ✅ Deleted: aug_1703_R302_ch1_video_04_00-20-37-25.jpg
# ✅ Deleted: aug_2231_R015_ch1_video_03_00-31-22-20.jpg
# ✅ Deleted: aug_889_R305_ch1_video_04_00-41-24-23.jpg
# ✅ Deleted: aug_1025_R019_ch1_video_05_00-11-19-07.jpg
# ✅ Deleted: aug_918_R010_ch1_video_03_00-24-40-05.jpg
# ✅ Deleted: aug_2398_R074_ch1_video_01_00-53-27-25.jpg
# ✅ Deleted: aug_2069_R202_ch1_video_05_00-34-58-09.jpg
# ✅ Deleted: aug_582_R117_ch1_video_03_00-35-36-02.jpg
# ✅ Deleted: aug_274_R007_ch1_video_04_00-14-38-12.jpg
# ✅ Deleted: aug_2165_R015_ch1_video_03_00-38-09-02.jpg
# ✅ Deleted: aug_1077_R305_ch1_video_04_00-00-01-20.jpg
# ✅ Deleted: aug_830_R203_ch1_video_03_00-31-08-06.jpg
# ✅ Deleted: aug_1148_R094_ch1_video_03_00-01-03-19.jpg
# ✅ Deleted: aug_1614_R094_ch1_video_03_00-02-01-17.jpg
# ✅ Deleted: aug_1160_R005_ch1_video_03_00-18-52-00.jpg
# ✅ Deleted: aug_881_R014_ch1_video_03_01-14-24-10.jpg
# ✅ Deleted: aug_1235_R117_ch1_video_03_00-35-21-03.jpg
# ✅ Deleted: aug_2108_R210_ch1_video_01_00-53-01-16.jpg
# ✅ Deleted: aug_1539_R304_ch1_video_03_00-48-17-07.jpg
# ✅ Deleted: aug_1682_R014_ch1_video_03_01-03-37-17.jpg
# ✅ Deleted: aug_1762_R203_ch1_video_03_00-28-17-18.jpg
# ✅ Deleted: aug_2359_R117_ch1_video_03_00-35-58-04.jpg
# ✅ Deleted: aug_902_R203_ch1_video_03_00-26-45-09.jpg
# ✅ Deleted: aug_633_R005_ch1_video_03_00-19-05-02.jpg
# ✅ Deleted: aug_2355_R117_ch1_video_01_00-54-18-00.jpg
# ✅ Deleted: aug_283_R010_ch1_video_03_00-25-18-07.jpg
# ✅ Deleted: aug_2438_R019_ch1_video_03_00-33-26-10.jpg
# ✅ Deleted: aug_354_R074_ch1_video_03_00-22-38-06.jpg
# ✅ Deleted: aug_1438_R100_ch1_video_01_01-15-03-07.jpg
# ✅ Deleted: aug_1743_R302_ch1_video_04_00-28-34-18.jpg
# ✅ Deleted: aug_2004_R094_ch1_video_01_01-14-52-29.jpg
# ✅ Deleted: aug_1401_R084_ch1_video_03_00-41-31-14.jpg
# ✅ Deleted: aug_2141_R201_ch1_video_03_00-36-51-12.jpg
# ✅ Deleted: aug_364_R010_ch1_video_01_00-32-07-14.jpg
# ✅ Deleted: aug_1535_R204_ch1_video_02_00-38-42-18.jpg
# ✅ Deleted: aug_1955_R005_ch1_video_01_00-19-26-06.jpg
# ✅ Deleted: aug_1461_R015_ch1_video_03_00-36-47-27.jpg
# ✅ Deleted: aug_1726_R010_ch1_video_03_00-25-12-14.jpg
# ✅ Deleted: aug_1680_R001_ch1_video_03_01-11-44-17.jpg
# ✅ Deleted: aug_2377_R002_ch1_video_01_00-49-11-28.jpg
# ✅ Deleted: aug_1575_R117_ch1_video_03_00-35-56-02.jpg
# ✅ Deleted: aug_180_R201_ch1_video_03_00-07-43-11.jpg
# ✅ Deleted: aug_1395_R203_ch1_video_03_00-14-49-12.jpg
# ✅ Deleted: aug_332_R204_ch1_video_02_00-39-45-13.jpg
# ✅ Deleted: aug_1404_R201_ch1_video_03_00-39-53-10.jpg
# ✅ Deleted: aug_634_R002_ch1_video_03_00-29-50-01.jpg
# ✅ Deleted: aug_1062_R002_ch1_video_01_00-49-11-28.jpg
# ✅ Deleted: aug_681_R014_ch1_video_03_01-03-37-17.jpg
# ✅ Deleted: aug_379_R056_ch1_video_01_00-39-45-20.jpg
# ✅ Deleted: aug_1775_R005_ch1_video_03_00-18-52-00.jpg
# ✅ Deleted: aug_1903_R014_ch1_video_03_00-23-24-04.jpg
# ✅ Deleted: aug_1408_R094_ch1_video_03_00-00-37-19.jpg
# ✅ Deleted: aug_2198_R015_ch1_video_03_00-38-09-02.jpg
# ✅ Deleted: aug_2490_R302_ch1_video_01_00-56-03-16.jpg
# ✅ Deleted: aug_1638_R010_ch1_video_01_00-32-23-23.jpg
# ✅ Deleted: aug_84_R209_ch1_video_03_01-07-08-23.jpg
# ✅ Deleted: aug_1183_R007_ch1_video_01_00-47-24-03.jpg
# ✅ Deleted: aug_642_R305_ch1_video_04_00-26-16-17.jpg
# ✅ Deleted: aug_978_R302_ch1_video_01_00-55-21-00.jpg
# ✅ Deleted: aug_1801_R014_ch1_video_03_00-07-49-22.jpg
# ✅ Deleted: aug_1112_R014_ch1_video_03_01-14-19-09.jpg
# ✅ Deleted: aug_2453_R019_ch1_video_05_00-11-02-05.jpg
# ✅ Deleted: aug_915_R210_ch1_video_01_00-53-01-16.jpg
# ✅ Deleted: aug_2021_R019_ch1_video_05_00-11-02-05.jpg
# ✅ Deleted: aug_1905_R015_ch1_video_03_00-31-22-20.jpg
# ✅ Deleted: aug_1894_R048_ch1_video_02_00-41-03-29.jpg
# ✅ Deleted: aug_496_R201_ch1_video_03_00-39-58-17.jpg
# ✅ Deleted: aug_1115_R019_ch1_video_01_00-48-37-20.jpg
# ✅ Deleted: aug_1069_R015_ch1_video_03_00-39-16-06.jpg
# ✅ Deleted: aug_1231_R205_ch1_video_05_00-00-42-29.jpg
# ✅ Deleted: aug_2072_R209_ch1_video_03_01-10-32-00.jpg
# ✅ Deleted: aug_763_R002_ch1_video_03_00-41-02-20.jpg
# ✅ Deleted: aug_689_R015_ch1_video_01_00-57-06-15.jpg
# ✅ Deleted: aug_308_R301_ch1_video_01_00-58-23-00.jpg
# ✅ Deleted: aug_2102_R206_ch1_video_03_00-03-09-28.jpg
# ✅ Deleted: aug_2171_R209_ch1_video_03_01-11-41-15.jpg
# ✅ Deleted: aug_1277_R005_ch1_video_03_00-19-30-11.jpg
# ✅ Deleted: aug_1482_R084_ch1_video_03_00-02-27-12.jpg
# ✅ Deleted: aug_1109_R117_ch1_video_03_00-17-35-21.jpg
# ✅ Deleted: aug_1135_R076_ch1_video_03_00-33-38-00.jpg
# ✅ Deleted: aug_1316_R002_ch1_video_01_00-58-54-01.jpg
# ✅ Deleted: aug_268_R203_ch1_video_03_00-25-00-06.jpg
# ✅ Deleted: aug_923_R084_ch1_video_03_00-57-31-04.jpg
# ✅ Deleted: aug_846_R094_ch1_video_03_00-00-56-19.jpg
# ✅ Deleted: aug_349_R301_ch1_video_04_00-18-50-16.jpg
# ✅ Deleted: aug_2481_R002_ch1_video_01_00-47-49-15.jpg
# ✅ Deleted: aug_1660_R084_ch1_video_03_00-36-32-19.jpg
# ✅ Deleted: aug_2305_R014_ch1_video_03_00-55-29-16.jpg
# ✅ Deleted: aug_2497_R002_ch1_video_01_00-41-27-13.jpg
# ✅ Deleted: aug_1199_R002_ch1_video_01_01-07-25-19.jpg
# ✅ Deleted: aug_1459_R014_ch1_video_03_00-23-42-05.jpg
# ✅ Deleted: aug_2032_R301_ch1_video_01_00-57-52-00.jpg
# ✅ Deleted: aug_2103_R209_ch1_video_03_01-11-41-15.jpg
# ✅ Deleted: aug_705_R002_ch1_video_01_01-00-13-01.jpg
# ✅ Deleted: aug_920_R005_ch1_video_03_00-10-46-28.jpg
# ✅ Deleted: aug_2063_R014_ch1_video_03_00-10-58-22.jpg
# ✅ Deleted: aug_844_R313_ch1_video_03_00-42-31-06.jpg
# ✅ Deleted: aug_883_R301_ch1_video_01_00-50-16-07.jpg
# ✅ Deleted: aug_630_R015_ch1_video_03_00-36-50-25.jpg
# ✅ Deleted: aug_2296_R002_ch1_video_03_00-40-26-12.jpg
# ✅ Deleted: aug_632_R201_ch1_video_03_00-39-58-17.jpg
# ✅ Deleted: aug_2049_R117_ch1_video_03_00-17-35-21.jpg
# ✅ Deleted: aug_2082_R015_ch1_video_01_00-57-06-15.jpg
# ✅ Deleted: aug_386_R007_ch1_video_01_00-47-24-03.jpg
# ✅ Deleted: aug_468_R014_ch1_video_03_01-14-29-10.jpg
# ✅ Deleted: aug_602_R094_ch1_video_03_00-02-01-17.jpg
# ✅ Deleted: aug_2186_R204_ch1_video_01_00-56-53-09.jpg
# ✅ Deleted: aug_2297_R305_ch1_video_04_00-41-14-13.jpg
# ✅ Deleted: aug_1204_R002_ch1_video_03_00-40-46-13.jpg
# ✅ Deleted: aug_471_R201_ch1_video_03_00-41-53-13.jpg
# ✅ Deleted: aug_199_R084_ch1_video_03_00-03-05-15.jpg
# ✅ Deleted: aug_2135_R117_ch1_video_03_00-35-47-01.jpg
# ✅ Deleted: aug_946_R204_ch1_video_02_00-40-10-08.jpg
# ✅ Deleted: aug_2303_R002_ch1_video_01_00-49-11-28.jpg
# ✅ Deleted: aug_324_R204_ch1_video_02_00-39-14-20.jpg
# ✅ Deleted: aug_1253_R094_ch1_video_03_00-01-03-19.jpg
# ✅ Deleted: aug_385_R305_ch1_video_04_00-29-37-01.jpg
# ✅ Deleted: aug_456_R002_ch1_video_01_00-59-00-27.jpg
# ✅ Deleted: aug_1856_R010_ch1_video_01_00-37-51-25.jpg
# ✅ Deleted: aug_412_R001_ch1_video_03_01-11-57-19.jpg
# ✅ Deleted: aug_1217_R094_ch1_video_03_00-00-37-29.jpg
# ✅ Deleted: aug_1946_R002_ch1_video_01_00-59-00-27.jpg
# ✅ Deleted: aug_1214_R002_ch1_video_01_01-04-17-11.jpg
# ✅ Deleted: aug_2271_R209_ch1_video_03_01-10-32-00.jpg
# ✅ Deleted: aug_211_R005_ch1_video_01_00-48-51-24.jpg
# ✅ Deleted: aug_693_R014_ch1_video_03_00-23-12-03.jpg
# ✅ Deleted: aug_1837_R002_ch1_video_03_00-29-50-01.jpg
# ✅ Deleted: aug_757_R305_ch1_video_04_00-29-37-01.jpg
# ✅ Deleted: aug_1678_R094_ch1_video_01_01-14-37-07.jpg
# ✅ Deleted: aug_884_R301_ch1_video_04_00-38-20-22.jpg
# ✅ Deleted: aug_659_R001_ch1_video_03_00-52-00-17.jpg
# ✅ Deleted: aug_2283_R002_ch1_video_01_00-41-54-26.jpg
# ✅ Deleted: aug_2152_R084_ch1_video_03_00-57-47-18.jpg
# ✅ Deleted: aug_1386_R010_ch1_video_01_00-32-23-23.jpg
# ✅ Deleted: aug_2181_R001_ch1_video_03_01-13-02-01.jpg
# ✅ Deleted: aug_1425_R117_ch1_video_01_00-51-26-10.jpg
# ✅ Deleted: aug_2260_R015_ch1_video_01_00-40-06-07.jpg
# ✅ Deleted: aug_762_R084_ch1_video_03_00-02-27-12.jpg
# ✅ Deleted: aug_613_R305_ch1_video_04_00-26-16-21.jpg
# ✅ Deleted: aug_1501_R014_ch1_video_03_01-14-13-20.jpg
# ✅ Deleted: aug_2475_R084_ch1_video_03_00-05-26-12.jpg
# ✅ Deleted: aug_229_R206_ch1_video_03_00-02-28-16.jpg
# ✅ Deleted: aug_888_R304_ch1_video_03_00-48-13-04.jpg
# ✅ Deleted: aug_1153_R201_ch1_video_03_00-37-16-24.jpg
# ✅ Deleted: aug_1481_R203_ch1_video_03_00-26-43-02.jpg
# ✅ Deleted: aug_1275_R117_ch1_video_03_00-34-45-04.jpg
# ✅ Deleted: aug_1452_R204_ch1_video_02_00-39-14-20.jpg
# ✅ Deleted: aug_860_R205_ch1_video_03_01-16-32-22.jpg
# ✅ Deleted: aug_924_R002_ch1_video_03_00-41-17-13.jpg
# ✅ Deleted: aug_1350_R117_ch1_video_01_00-39-23-10.jpg
# ✅ Deleted: aug_1288_R001_ch1_video_01_00-57-36-10.jpg
# ✅ Deleted: aug_534_R015_ch1_video_01_00-57-06-15.jpg
# ✅ Deleted: aug_1628_R005_ch1_video_03_00-18-52-00.jpg
# ✅ Deleted: aug_1194_R010_ch1_video_01_00-37-51-25.jpg
# ✅ Deleted: aug_984_R210_ch2_video_04_00-08-31-07.jpg
# ✅ Deleted: aug_2025_R014_ch1_video_03_01-03-31-13.jpg
# ✅ Deleted: aug_1075_R001_ch1_video_03_01-11-44-17.jpg
# ✅ Deleted: aug_1969_R201_ch1_video_03_00-41-29-25.jpg
# ✅ Deleted: aug_337_R074_ch1_video_01_00-52-54-24.jpg
# ✅ Deleted: aug_1446_R203_ch1_video_03_00-25-00-06.jpg
# ✅ Deleted: aug_2280_R015_ch1_video_03_00-37-00-25.jpg
# ✅ Deleted: aug_625_R305_ch1_video_04_00-36-35-15.jpg
# ✅ Deleted: aug_1380_R010_ch1_video_01_00-32-23-23.jpg
# ✅ Deleted: aug_2223_R001_ch1_video_03_01-04-03-09.jpg
# ✅ Deleted: aug_1313_R207_ch1_video_03_00-31-21-00.jpg
# ✅ Deleted: aug_2277_R002_ch1_video_03_00-40-52-30.jpg
# ✅ Deleted: aug_1424_R001_ch1_video_03_00-57-53-26.jpg
# ✅ Deleted: aug_2304_R084_ch1_video_03_00-03-01-09.jpg
# ✅ Deleted: aug_350_R005_ch1_video_03_00-18-54-17.jpg
# ✅ Deleted: aug_2185_R301_ch1_video_04_00-17-18-20.jpg
# ✅ Deleted: aug_1665_R084_ch1_video_03_00-03-01-09.jpg
# ✅ Deleted: aug_105_R084_ch1_video_03_00-57-39-16.jpg
# ✅ Deleted: aug_1040_R001_ch1_video_03_01-11-51-25.jpg
# ✅ Deleted: aug_703_R010_ch1_video_01_00-38-04-25.jpg
# ✅ Deleted: aug_2003_R305_ch1_video_04_00-01-00-08.jpg
# ✅ Deleted: aug_1749_R203_ch1_video_03_00-16-53-06.jpg
# ✅ Deleted: aug_182_R084_ch1_video_03_00-36-32-19.jpg
# ✅ Deleted: aug_1751_R014_ch1_video_03_01-14-24-10.jpg
# ✅ Deleted: aug_2183_R015_ch1_video_03_00-39-16-06.jpg
# ✅ Deleted: aug_439_R305_ch1_video_04_00-41-19-16.jpg
# ✅ Deleted: aug_163_R094_ch1_video_03_00-00-37-19.jpg
# ✅ Deleted: aug_1022_R205_ch1_video_05_00-00-00-20.jpg
# ✅ Deleted: aug_1089_R304_ch1_video_03_00-48-02-00.jpg
# ✅ Deleted: aug_563_R094_ch1_video_03_00-00-37-19.jpg
# ✅ Deleted: aug_3_R304_ch1_video_03_00-48-02-00.jpg
# ✅ Deleted: aug_315_R010_ch1_video_01_00-32-07-14.jpg
# ✅ Deleted: aug_1834_R203_ch1_video_03_00-30-51-18.jpg
# ✅ Deleted: aug_835_R001_ch1_video_03_01-11-57-19.jpg
# ✅ Deleted: aug_345_R210_ch1_video_01_00-39-37-09.jpg
# ✅ Deleted: aug_929_R201_ch1_video_03_00-40-02-24.jpg
# ✅ Deleted: aug_1318_R007_ch1_video_01_00-46-44-27.jpg
# ✅ Deleted: aug_1295_R015_ch1_video_03_00-36-38-25.jpg
# ✅ Deleted: aug_1248_R201_ch1_video_03_00-40-02-24.jpg
# ✅ Deleted: aug_1155_R001_ch1_video_03_01-11-57-19.jpg
# ✅ Deleted: aug_1057_R305_ch1_video_01_01-00-34-25.jpg
# ✅ Deleted: aug_575_R206_ch1_video_01_01-15-30-05.jpg
# ✅ Deleted: aug_2485_R010_ch1_video_03_00-24-40-05.jpg
# ✅ Deleted: aug_1308_R005_ch1_video_03_00-18-54-00.jpg
# ✅ Deleted: aug_702_R084_ch1_video_03_00-41-31-14.jpg
# ✅ Deleted: aug_836_R117_ch1_video_03_00-23-58-01.jpg
# ✅ Deleted: aug_639_R209_ch1_video_03_01-10-35-15.jpg
# ✅ Deleted: aug_2381_R010_ch1_video_01_00-38-04-25.jpg
# ✅ Deleted: aug_679_R001_ch1_video_03_01-11-46-17.jpg
# ✅ Deleted: aug_1018_R201_ch1_video_03_00-27-19-22.jpg
# ✅ Deleted: aug_1968_R313_ch1_video_03_00-42-31-11.jpg
# ✅ Deleted: aug_532_R002_ch1_video_01_01-04-17-11.jpg
# ✅ Deleted: aug_279_R084_ch1_video_03_00-57-31-04.jpg
# ✅ Deleted: aug_2434_R117_ch1_video_03_00-24-20-24.jpg
# ✅ Deleted: aug_1108_R002_ch1_video_03_00-29-50-01.jpg
# ✅ Deleted: aug_1532_R305_ch1_video_04_00-00-01-20.jpg
# ✅ Deleted: aug_652_R084_ch1_video_03_00-59-23-00.jpg
# ✅ Deleted: aug_256_R201_ch1_video_03_00-41-29-25.jpg
# ✅ Deleted: aug_316_R203_ch1_video_03_00-26-51-09.jpg
# ✅ Deleted: aug_1014_R209_ch1_video_03_01-13-10-00.jpg
# ✅ Deleted: aug_1506_R117_ch1_video_01_00-51-39-27.jpg
# ✅ Deleted: aug_83_R019_ch1_video_03_00-33-26-10.jpg
# ✅ Deleted: aug_244_R094_ch1_video_03_00-00-37-19.jpg
# ✅ Deleted: aug_1740_R001_ch1_video_01_01-12-47-27.jpg
# ✅ Deleted: aug_521_R210_ch2_video_04_00-06-00-02.jpg
# ✅ Deleted: aug_862_R203_ch1_video_03_00-11-03-14.jpg
# ✅ Deleted: aug_1479_R015_ch1_video_03_00-36-54-27.jpg
# ✅ Deleted: aug_714_R001_ch1_video_01_00-57-14-23.jpg
# ✅ Deleted: aug_45_R014_ch1_video_03_00-24-31-18.jpg
# ✅ Deleted: aug_2168_R209_ch1_video_03_01-13-10-00.jpg
# ✅ Deleted: aug_1625_R014_ch1_video_03_01-03-31-13.jpg
# ✅ Deleted: aug_1264_R015_ch1_video_03_00-36-50-25.jpg
# ✅ Deleted: aug_2412_R010_ch1_video_03_00-25-12-14.jpg
# ✅ Deleted: aug_2499_R074_ch1_video_01_00-28-30-08.jpg
# ✅ Deleted: aug_1493_R015_ch1_video_03_00-37-34-26.jpg
# ✅ Deleted: aug_243_R005_ch1_video_03_00-19-10-11.jpg
# ✅ Deleted: aug_1850_R010_ch1_video_03_00-25-12-14.jpg
# ✅ Deleted: aug_1092_R084_ch1_video_03_00-03-01-09.jpg
# ✅ Deleted: aug_1952_R014_ch1_video_03_00-23-34-05.jpg
# ✅ Deleted: aug_1444_R301_ch1_video_04_00-36-59-13.jpg
# ✅ Deleted: aug_1462_R001_ch1_video_03_01-01-48-04.jpg
# ✅ Deleted: aug_1994_R301_ch1_video_04_00-36-59-13.jpg
# ✅ Deleted: aug_348_R001_ch1_video_03_01-11-57-19.jpg
# ✅ Deleted: aug_391_R001_ch1_video_01_01-10-49-01.jpg
# ✅ Deleted: aug_2030_R001_ch1_video_03_00-15-41-20.jpg
# ✅ Deleted: aug_1186_R117_ch1_video_01_00-52-05-19.jpg
# ✅ Deleted: aug_491_R001_ch1_video_03_00-55-04-15.jpg
# ✅ Deleted: aug_2060_R056_ch1_video_01_00-39-45-20.jpg
# ✅ Deleted: aug_100_R074_ch1_video_01_00-28-30-08.jpg
# ✅ Deleted: aug_232_R015_ch1_video_03_00-36-38-25.jpg
# ✅ Deleted: aug_47_R304_ch1_video_03_00-48-13-04.jpg
# ✅ Deleted: aug_796_R209_ch1_video_03_01-13-19-01.jpg
# ✅ Deleted: aug_1983_R001_ch1_video_01_00-57-14-23.jpg
# ✅ Deleted: aug_518_R002_ch1_video_01_01-04-17-11.jpg
# ✅ Deleted: aug_1381_R002_ch1_video_01_00-59-35-06.jpg
# ✅ Deleted: aug_2027_R210_ch2_video_04_00-06-00-02.jpg
# ✅ Deleted: aug_186_R304_ch1_video_03_00-48-01-14.jpg
# ✅ Deleted: aug_226_R014_ch1_video_03_01-03-37-17.jpg
# ✅ Deleted: aug_519_R313_ch1_video_03_00-20-54-07.jpg
# ✅ Deleted: aug_569_R117_ch1_video_03_00-34-45-04.jpg
# ✅ Deleted: aug_1561_R210_ch2_video_04_00-08-36-07.jpg
# ✅ Deleted: aug_939_R204_ch1_video_02_00-39-45-13.jpg
# ✅ Deleted: aug_1090_R015_ch1_video_01_00-57-23-16.jpg
# ✅ Deleted: aug_2106_R205_ch1_video_05_00-14-42-22.jpg
# ✅ Deleted: aug_1435_R304_ch1_video_03_00-48-02-00.jpg
# ✅ Deleted: aug_99_R203_ch1_video_03_00-28-17-18.jpg
# ✅ Deleted: aug_2006_R205_ch1_video_03_00-31-59-18.jpg
# ✅ Deleted: aug_1399_R074_ch1_video_03_00-23-03-08.jpg
# ✅ Deleted: aug_258_R117_ch1_video_01_00-39-23-10.jpg
# ✅ Deleted: aug_1885_R204_ch1_video_01_00-51-18-00.jpg
# ✅ Deleted: aug_2247_R301_ch1_video_01_00-44-24-00.jpg
# ✅ Deleted: aug_1831_R014_ch1_video_03_01-14-24-10.jpg
# ✅ Deleted: aug_1700_R005_ch1_video_01_00-24-56-18.jpg
# ✅ Deleted: aug_2167_R014_ch1_video_03_01-03-19-26.jpg
# ✅ Deleted: aug_1613_R203_ch1_video_03_00-28-17-18.jpg
# ✅ Deleted: aug_1434_R203_ch1_video_03_00-28-32-19.jpg
# ✅ Deleted: aug_2144_R209_ch1_video_03_01-11-47-13.jpg
# ✅ Deleted: aug_2289_R007_ch1_video_01_00-47-54-03.jpg
# ✅ Deleted: aug_2492_R014_ch1_video_03_01-14-19-09.jpg
# ✅ Deleted: aug_1306_R117_ch1_video_03_00-35-36-02.jpg
# ✅ Deleted: aug_1207_R203_ch1_video_03_00-31-08-06.jpg
# ✅ Deleted: aug_2479_R209_ch1_video_03_01-11-41-15.jpg
# ✅ Deleted: aug_1509_R002_ch1_video_01_01-06-56-20.jpg
# ✅ Deleted: aug_1133_R204_ch1_video_02_00-38-42-18.jpg
# ✅ Deleted: aug_392_R210_ch2_video_04_00-10-08-12.jpg
# ✅ Deleted: aug_1465_R209_ch1_video_03_01-13-19-01.jpg
# ✅ Deleted: aug_2195_R002_ch1_video_01_00-58-54-01.jpg
# ✅ Deleted: aug_64_R094_ch1_video_03_00-00-40-19.jpg
# ✅ Deleted: aug_1103_R094_ch1_video_01_01-10-37-17.jpg
# ✅ Deleted: aug_141_R117_ch1_video_01_00-52-06-12.jpg
# ✅ Deleted: aug_1906_R305_ch1_video_04_00-00-01-20.jpg
# ✅ Deleted: aug_1510_R301_ch1_video_01_00-58-23-00.jpg
# ✅ Deleted: aug_2164_R209_ch1_video_03_01-11-47-13.jpg
# ✅ Deleted: aug_133_R204_ch1_video_02_00-38-42-18.jpg
# ✅ Deleted: aug_1441_R117_ch1_video_01_00-52-06-12.jpg
# ✅ Deleted: aug_2122_R204_ch1_video_02_00-39-08-13.jpg
# ✅ Deleted: aug_43_R002_ch1_video_01_00-41-54-26.jpg
# ✅ Deleted: aug_1870_R001_ch1_video_01_01-12-47-27.jpg
# ✅ Deleted: aug_2002_R084_ch1_video_03_00-03-05-15.jpg
# ✅ Deleted: aug_251_R209_ch1_video_03_01-14-32-00.jpg
# ✅ Deleted: aug_654_R001_ch1_video_03_01-11-51-25.jpg
# ✅ Deleted: aug_1174_R019_ch1_video_05_00-11-27-28.jpg
# ✅ Deleted: aug_1107_R201_ch1_video_03_00-39-58-17.jpg
# ✅ Deleted: aug_2325_R203_ch1_video_03_00-30-12-28.jpg
# ✅ Deleted: aug_2148_R117_ch1_video_03_00-35-56-02.jpg
# ✅ Deleted: aug_1892_R001_ch1_video_01_01-10-49-01.jpg
# ✅ Deleted: aug_1808_R201_ch1_video_03_00-40-02-24.jpg
# ✅ Deleted: aug_1021_R010_ch1_video_01_00-32-23-23.jpg
# ✅ Deleted: aug_1733_R302_ch1_video_04_00-27-42-03.jpg
# ✅ Deleted: aug_790_R117_ch1_video_03_00-35-44-02.jpg
# ✅ Deleted: aug_1052_R210_ch2_video_04_00-10-12-05.jpg
# ✅ Deleted: aug_1696_R005_ch1_video_01_00-48-51-24.jpg
# ✅ Deleted: aug_928_R019_ch1_video_05_00-11-19-07.jpg
# ✅ Deleted: aug_1146_R019_ch1_video_03_00-33-26-10.jpg
# ✅ Deleted: aug_357_R019_ch1_video_05_00-11-10-16.jpg
# ✅ Deleted: aug_252_R094_ch1_video_03_00-00-45-19.jpg
# ✅ Deleted: aug_670_R117_ch1_video_03_00-34-13-14.jpg
# ✅ Deleted: aug_606_R201_ch1_video_03_00-37-39-20.jpg
# ✅ Deleted: aug_124_R001_ch1_video_01_01-11-41-09.jpg
# ✅ Deleted: aug_172_R015_ch1_video_01_00-57-23-16.jpg
# ✅ Deleted: aug_926_R304_ch1_video_03_00-47-50-23.jpg
# ✅ Deleted: aug_1586_R001_ch1_video_03_01-13-30-01.jpg
# ✅ Deleted: aug_2062_R205_ch1_video_05_00-00-02-20.jpg
# ✅ Deleted: aug_1448_R203_ch1_video_03_00-31-08-06.jpg
# ✅ Deleted: aug_1006_R203_ch1_video_03_00-28-32-19.jpg
# ✅ Deleted: aug_2128_R002_ch1_video_03_00-25-08-15.jpg
# ✅ Deleted: aug_1770_R094_ch1_video_03_00-00-40-19.jpg
# ✅ Deleted: aug_286_R001_ch1_video_03_00-52-00-17.jpg
# ✅ Deleted: aug_2496_R048_ch1_video_02_00-11-41-16.jpg
# ✅ Deleted: aug_1433_R201_ch1_video_03_00-41-44-26.jpg
# ✅ Deleted: aug_1047_R203_ch1_video_03_00-16-53-06.jpg
# ✅ Deleted: aug_2242_R014_ch1_video_03_01-14-19-09.jpg
# ✅ Deleted: aug_2270_R205_ch1_video_03_00-28-36-14.jpg
# ✅ Deleted: aug_1766_R094_ch1_video_01_00-38-15-05.jpg
# ✅ Deleted: aug_699_R305_ch1_video_04_00-01-14-12.jpg
# ✅ Deleted: aug_140_R313_ch1_video_03_00-42-42-18.jpg
# ✅ Deleted: aug_2471_R076_ch1_video_01_00-45-38-05.jpg
# ✅ Deleted: aug_2080_R203_ch1_video_03_00-16-53-06.jpg
# ✅ Deleted: aug_651_R002_ch1_video_03_00-40-36-02.jpg
# ✅ Deleted: aug_1620_R015_ch1_video_03_00-38-09-02.jpg
# ✅ Deleted: aug_441_R084_ch1_video_03_00-05-26-12.jpg
# ✅ Deleted: aug_1736_R014_ch1_video_03_00-24-31-18.jpg
# ✅ Deleted: aug_372_R201_ch1_video_03_00-37-16-24.jpg
# ✅ Deleted: aug_873_R014_ch1_video_03_01-03-25-04.jpg
# ✅ Deleted: aug_1211_R094_ch1_video_01_01-14-52-29.jpg
# ✅ Deleted: aug_2215_R094_ch1_video_01_01-14-52-29.jpg
# ✅ Deleted: aug_1663_R015_ch1_video_03_00-36-55-25.jpg
# ✅ Deleted: aug_192_R313_ch1_video_03_00-42-36-13.jpg
# ✅ Deleted: aug_305_R015_ch1_video_03_00-38-09-02.jpg
# ✅ Deleted: aug_367_R117_ch1_video_03_00-34-13-14.jpg
# ✅ Deleted: aug_1658_R014_ch1_video_03_00-27-26-05.jpg
# ✅ Deleted: aug_458_R015_ch1_video_03_00-37-03-25.jpg
# ✅ Deleted: aug_1866_R203_ch1_video_03_00-11-03-14.jpg
# ✅ Deleted: aug_2316_R206_ch1_video_01_01-15-30-05.jpg
# ✅ Deleted: aug_1891_R010_ch1_video_01_00-32-07-14.jpg
# ✅ Deleted: aug_1119_R084_ch1_video_03_00-03-05-15.jpg
# ✅ Deleted: aug_1208_R002_ch1_video_01_00-41-38-11.jpg
# ✅ Deleted: aug_2047_R201_ch1_video_03_00-07-42-07.jpg
# ✅ Deleted: aug_1919_R001_ch1_video_03_01-13-30-01.jpg
# ✅ Deleted: aug_1378_R094_ch1_video_03_00-00-37-19.jpg
# ✅ Deleted: aug_112_R001_ch1_video_03_00-57-53-26.jpg
# ✅ Deleted: aug_603_R305_ch1_video_04_00-29-37-01.jpg
# ✅ Deleted: aug_60_R001_ch1_video_03_01-13-02-01.jpg
# ✅ Deleted: aug_1312_R117_ch1_video_01_00-52-06-12.jpg
# ✅ Deleted: aug_227_R210_ch2_video_04_00-14-52-02.jpg
# ✅ Deleted: aug_29_R117_ch1_video_03_00-35-36-02.jpg
# ✅ Deleted: aug_1548_R301_ch1_video_04_00-17-18-20.jpg
# ✅ Deleted: aug_1180_R207_ch1_video_03_00-31-21-00.jpg
# ✅ Deleted: aug_297_R205_ch1_video_05_00-05-23-14.jpg
# ✅ Deleted: aug_1238_R002_ch1_video_01_00-47-49-15.jpg
# ✅ Deleted: aug_820_R084_ch1_video_03_00-57-39-16.jpg
# ✅ Deleted: aug_2404_R056_ch1_video_01_00-39-18-04.jpg
# ✅ Deleted: aug_535_R074_ch1_video_01_00-52-54-22.jpg
# ✅ Deleted: aug_219_R005_ch1_video_01_00-49-32-21.jpg
# ✅ Deleted: aug_1165_R084_ch1_video_03_00-57-44-25.jpg
# ✅ Deleted: aug_1132_R005_ch1_video_03_00-19-05-02.jpg
# ✅ Deleted: aug_2494_R301_ch1_video_04_00-20-10-01.jpg
# ✅ Deleted: aug_1368_R204_ch1_video_02_00-40-21-06.jpg
# ✅ Deleted: aug_1296_R301_ch1_video_04_00-20-11-13.jpg
# ✅ Deleted: aug_1542_R005_ch1_video_03_00-18-54-00.jpg
# ✅ Deleted: aug_585_R084_ch1_video_03_00-43-01-16.jpg
# ✅ Deleted: aug_704_R094_ch1_video_03_00-02-01-17.jpg
# ✅ Deleted: aug_777_R305_ch1_video_04_00-27-00-08.jpg
# ✅ Deleted: aug_880_R084_ch1_video_03_00-36-32-19.jpg
# ✅ Deleted: aug_1302_R010_ch1_video_01_00-40-39-20.jpg
# ✅ Deleted: aug_1375_R305_ch1_video_04_00-27-00-08.jpg
# ✅ Deleted: aug_673_R205_ch1_video_05_00-12-56-27.jpg
# ✅ Deleted: aug_1054_R084_ch1_video_03_00-57-44-25.jpg
# ✅ Deleted: aug_1790_R201_ch1_video_03_00-41-53-13.jpg
# ✅ Deleted: aug_71_R014_ch1_video_03_00-07-49-22.jpg
# ✅ Deleted: aug_967_R084_ch1_video_03_00-57-39-16.jpg
# ✅ Deleted: aug_891_R203_ch1_video_03_00-18-34-16.jpg
# ✅ Deleted: aug_1427_R084_ch1_video_03_00-41-31-14.jpg
# ✅ Deleted: aug_636_R206_ch1_video_01_01-15-30-05.jpg
# ✅ Deleted: aug_621_R210_ch2_video_04_00-04-39-13.jpg
# ✅ Deleted: aug_1035_R204_ch1_video_02_00-40-21-06.jpg
# ✅ Deleted: aug_1820_R002_ch1_video_03_00-29-50-01.jpg
# ✅ Deleted: aug_363_R048_ch1_video_02_00-13-46-15.jpg
# ✅ Deleted: aug_2266_R210_ch2_video_04_00-10-12-05.jpg
# ✅ Deleted: aug_597_R002_ch1_video_01_00-47-49-15.jpg
# ✅ Deleted: aug_1937_R100_ch1_video_01_00-48-54-07.jpg
# ✅ Deleted: aug_403_R014_ch1_video_03_01-03-43-17.jpg
# ✅ Deleted: aug_2243_R084_ch1_video_03_00-59-39-16.jpg
# ✅ Deleted: aug_90_R203_ch1_video_03_00-16-53-06.jpg
# ✅ Deleted: aug_164_R304_ch1_video_03_00-48-54-18.jpg
# ✅ Deleted: aug_2217_R117_ch1_video_01_00-51-39-27.jpg
# ✅ Deleted: aug_2090_R305_ch1_video_04_00-27-00-08.jpg
# ✅ Deleted: aug_2196_R002_ch1_video_01_00-41-27-13.jpg
# ✅ Deleted: aug_537_R019_ch1_video_05_00-11-23-08.jpg
# ✅ Deleted: aug_1588_R014_ch1_video_03_01-14-19-20.jpg
# ✅ Deleted: aug_1877_R002_ch1_video_01_01-04-17-11.jpg
# ✅ Deleted: aug_1236_R201_ch1_video_03_00-27-31-09.jpg
# ✅ Deleted: aug_1719_R014_ch1_video_03_01-03-31-13.jpg
# ✅ Deleted: aug_1890_R015_ch1_video_03_00-37-36-26.jpg
# ✅ Deleted: aug_961_R204_ch1_video_01_00-51-18-00.jpg
# ✅ Deleted: aug_2156_R084_ch1_video_03_00-57-31-04.jpg
# ✅ Deleted: aug_635_R205_ch1_video_05_00-14-42-22.jpg
# ✅ Deleted: aug_712_R305_ch1_video_04_00-38-07-02.jpg
# ✅ Deleted: aug_2435_R313_ch1_video_03_00-42-54-26.jpg
# ✅ Deleted: aug_555_R015_ch1_video_03_00-18-54-08.jpg
# ✅ Deleted: aug_1045_R001_ch1_video_01_01-11-51-01.jpg
# ✅ Deleted: aug_2136_R001_ch1_video_01_01-11-51-01.jpg
# ✅ Deleted: aug_711_R117_ch1_video_03_00-34-45-04.jpg
# ✅ Deleted: aug_360_R084_ch1_video_03_00-57-39-16.jpg
# ✅ Deleted: aug_165_R210_ch2_video_04_00-08-31-07.jpg
# ✅ Deleted: aug_1203_R201_ch1_video_03_00-37-16-24.jpg
# ✅ Deleted: aug_799_R005_ch1_video_01_00-24-56-18.jpg
# ✅ Deleted: aug_1266_R014_ch1_video_03_00-07-49-22.jpg
# ✅ Deleted: aug_93_R313_ch1_video_03_00-43-17-02.jpg
# ✅ Deleted: aug_768_R010_ch1_video_01_00-38-04-25.jpg
# ✅ Deleted: aug_538_R007_ch1_video_01_00-47-30-03.jpg
# ✅ Deleted: aug_2484_R084_ch1_video_03_00-57-44-25.jpg
# ✅ Deleted: aug_257_R210_ch1_video_01_00-52-43-16.jpg
# ✅ Deleted: aug_1508_R084_ch1_video_03_00-57-39-16.jpg
# ✅ Deleted: aug_850_R056_ch1_video_01_00-39-18-04.jpg
# ✅ Deleted: aug_578_R301_ch1_video_04_00-17-18-20.jpg
# ✅ Deleted: aug_960_R019_ch1_video_01_00-48-37-20.jpg
# ✅ Deleted: aug_1536_R305_ch1_video_04_00-01-00-08.jpg
# ✅ Deleted: aug_641_R301_ch1_video_01_00-57-52-00.jpg
# ✅ Deleted: aug_94_R074_ch1_video_01_00-52-54-22.jpg
# ✅ Deleted: aug_1825_R005_ch1_video_03_00-19-05-02.jpg
# ✅ Deleted: aug_2437_R014_ch1_video_03_01-14-24-10.jpg
# ✅ Deleted: aug_2017_R084_ch1_video_03_00-57-47-18.jpg
# ✅ Deleted: aug_995_R117_ch1_video_03_00-23-58-01.jpg
# ✅ Deleted: aug_1661_R117_ch1_video_03_00-17-35-21.jpg
# ✅ Deleted: aug_1483_R002_ch1_video_01_00-41-27-13.jpg
# ✅ Deleted: aug_73_R117_ch1_video_03_00-23-58-01.jpg
# ✅ Deleted: aug_2476_R015_ch1_video_03_00-36-55-25.jpg
# ✅ Deleted: aug_1327_R209_ch1_video_03_01-13-19-01.jpg
# ✅ Deleted: aug_1534_R304_ch1_video_03_00-48-56-22.jpg
# ✅ Deleted: aug_2360_R015_ch1_video_03_00-37-34-26.jpg
# ✅ Deleted: aug_2125_R015_ch1_video_03_00-38-09-02.jpg
# ✅ Deleted: aug_451_R002_ch1_video_01_01-07-25-19.jpg
# ✅ Deleted: aug_2074_R304_ch1_video_03_00-41-03-02.jpg
# ✅ Deleted: aug_2192_R206_ch1_video_03_00-04-55-29.jpg
# ✅ Deleted: aug_2429_R117_ch1_video_03_00-17-35-21.jpg
# ✅ Deleted: aug_1960_R001_ch1_video_03_00-57-53-26.jpg
# ✅ Deleted: aug_38_R001_ch1_video_03_01-13-02-01.jpg
# ✅ Deleted: aug_1500_R304_ch1_video_03_00-48-02-00.jpg
# ✅ Deleted: aug_671_R002_ch1_video_03_00-40-47-29.jpg
# ✅ Deleted: aug_1672_R301_ch1_video_04_00-38-20-22.jpg
# ✅ Deleted: aug_463_R019_ch1_video_05_00-11-19-07.jpg
# ✅ Deleted: aug_2467_R117_ch1_video_03_00-23-58-01.jpg
# ✅ Deleted: aug_562_R001_ch1_video_03_01-00-36-26.jpg
# ✅ Deleted: aug_2086_R014_ch1_video_03_00-23-34-05.jpg
# ✅ Deleted: aug_1647_R015_ch1_video_03_00-37-58-02.jpg
# ✅ Deleted: aug_1701_R201_ch1_video_03_00-37-16-24.jpg
# ✅ Deleted: aug_1854_R305_ch1_video_04_00-38-07-02.jpg
# ✅ Deleted: aug_1143_R117_ch1_video_03_00-34-13-14.jpg
# ✅ Deleted: aug_2121_R207_ch1_video_03_00-34-17-08.jpg
# ✅ Deleted: aug_1367_R204_ch1_video_02_00-38-42-18.jpg
# ✅ Deleted: aug_2368_R010_ch1_video_03_00-25-18-05.jpg
# ✅ Deleted: aug_1_R304_ch1_video_03_00-48-54-18.jpg
# ✅ Deleted: aug_1201_R301_ch1_video_04_00-20-11-13.jpg
# ✅ Deleted: aug_1670_R117_ch1_video_03_00-36-04-00.jpg
# ✅ Deleted: aug_1938_R304_ch1_video_03_00-48-02-00.jpg
# ✅ Deleted: aug_810_R302_ch1_video_01_00-56-03-16.jpg
# ✅ Deleted: aug_648_R094_ch1_video_03_00-02-01-17.jpg
# ✅ Deleted: aug_435_R014_ch1_video_03_00-59-31-16.jpg
# ✅ Deleted: aug_782_R305_ch1_video_04_00-27-00-08.jpg
# ✅ Deleted: aug_2385_R015_ch1_video_01_00-57-23-16.jpg
# ✅ Deleted: aug_964_R305_ch1_video_01_01-14-43-02.jpg
# ✅ Deleted: aug_691_R117_ch1_video_03_00-35-55-29.jpg
# ✅ Deleted: aug_1633_R010_ch1_video_01_00-38-04-25.jpg
# ✅ Deleted: aug_825_R074_ch1_video_01_00-53-15-24.jpg
# ✅ Deleted: aug_2483_R084_ch1_video_03_00-57-44-25.jpg
# ✅ Deleted: aug_144_R014_ch1_video_03_00-59-31-16.jpg
# ✅ Deleted: aug_2486_R210_ch2_video_04_00-06-00-02.jpg
# ✅ Deleted: aug_1573_R301_ch1_video_04_00-15-24-02.jpg
# ✅ Deleted: aug_695_R005_ch1_video_03_00-19-30-11.jpg
# ✅ Deleted: aug_1518_R209_ch1_video_03_01-13-19-01.jpg
# ✅ Deleted: aug_604_R074_ch1_video_01_00-52-54-24.jpg
# ✅ Deleted: aug_719_R001_ch1_video_03_01-13-02-01.jpg
# ✅ Deleted: aug_408_R209_ch1_video_03_01-07-08-23.jpg
# ✅ Deleted: aug_1579_R305_ch1_video_04_00-26-16-17.jpg
# ✅ Deleted: aug_1413_R019_ch1_video_01_00-58-37-26.jpg
# ✅ Deleted: aug_488_R005_ch1_video_01_00-43-10-14.jpg
# ✅ Deleted: aug_1494_R094_ch1_video_01_01-14-52-29.jpg
# ✅ Deleted: aug_2158_R014_ch1_video_03_01-14-19-09.jpg
# ✅ Deleted: aug_442_R094_ch1_video_01_01-14-52-29.jpg
# ✅ Deleted: aug_221_R001_ch1_video_01_01-11-41-09.jpg
# ✅ Deleted: aug_116_R301_ch1_video_04_00-18-50-16.jpg
# ✅ Deleted: aug_1348_R084_ch1_video_03_00-57-39-16.jpg
# ✅ Deleted: aug_1659_R117_ch1_video_01_00-52-05-19.jpg
# ✅ Deleted: aug_2209_R305_ch1_video_04_00-26-16-17.jpg
# ✅ Deleted: aug_912_R001_ch1_video_03_00-57-53-26.jpg
# ✅ Deleted: aug_2065_R117_ch1_video_03_00-36-04-00.jpg
# ✅ Deleted: aug_1562_R076_ch1_video_03_00-18-53-06.jpg
# ✅ Deleted: aug_1999_R204_ch1_video_02_00-39-14-13.jpg
# ✅ Deleted: aug_2335_R084_ch1_video_03_00-41-35-16.jpg
# ✅ Deleted: aug_2378_R301_ch1_video_04_00-38-23-15.jpg
# ✅ Deleted: aug_1099_R201_ch1_video_03_00-27-19-22.jpg
# ✅ Deleted: aug_216_R007_ch1_video_01_00-47-30-03.jpg
# ✅ Deleted: aug_2365_R015_ch1_video_03_00-39-16-06.jpg
# ✅ Deleted: aug_298_R201_ch1_video_03_00-27-57-02.jpg
# ✅ Deleted: aug_2457_R313_ch1_video_03_00-42-49-03.jpg
# ✅ Deleted: aug_446_R313_ch1_video_03_00-42-42-18.jpg
# ✅ Deleted: aug_1385_R201_ch1_video_03_00-24-59-28.jpg
# ✅ Deleted: aug_1206_R301_ch1_video_04_00-20-10-01.jpg
# ✅ Deleted: aug_2124_R001_ch1_video_03_00-55-30-07.jpg
# ✅ Deleted: aug_746_R014_ch1_video_03_01-14-24-10.jpg
# ✅ Updated CSV saved to: /home/yash/Desktop/project/new dataset/train1/Pancreas/new_train2.csv
# ✅ 1000 augmented images deleted and CSV updated.

# %% [markdown]
# script to verify dataset

# %%
import os
import pandas as pd

# === CONFIGURATION ===
CSV_PATH = "/home/yash/Desktop/project/new dataset/ft3/main_labels.csv"
IMAGE_DIR = "/home/yash/Desktop/project/new dataset/ft3/"
OUTPUT_CSV = "/home/yash/Desktop/project/new dataset/ft3/cleaned_and_verified.csv"
LOG_PATH = "/home/yash/Desktop/project/new dataset/ft3/missing_images_log.txt"

# === LOAD CSV SAFELY: Read first column as filename, rest as label string
with open(CSV_PATH, 'r') as f:
    lines = f.readlines()

rows = []
for line in lines[1:]:  # Skip header
    parts = line.strip().split(",")
    if len(parts) >= 2:
        filename = parts[0]
        labels = ",".join(parts[1:])
        rows.append((filename, labels))

# === VERIFY IMAGES EXIST ===
all_images = set(os.listdir(IMAGE_DIR))
missing = []
verified_rows = []

for filename, labels in rows:
    if filename in all_images:
        verified_rows.append((filename, labels))
    else:
        missing.append(filename)

# === SAVE CLEANED CSV ===
df_clean = pd.DataFrame(verified_rows, columns=["filename", "labels"])
df_clean.to_csv(OUTPUT_CSV, index=False)

# === SAVE MISSING LOG ===
with open(LOG_PATH, 'w') as log:
    log.write("=== MISSING IMAGES ===\n")
    for fname in missing:
        log.write(f"{fname}\n")

print(f"✅ Cleaned CSV saved to: {OUTPUT_CSV}")
print(f"📝 Missing images logged to: {LOG_PATH}")
print(f"✅ Found {len(verified_rows)} images")
print(f"❌ Missing {len(missing)} images")
# Out:
# ✅ Cleaned CSV saved to: /home/yash/Desktop/project/new dataset/ft3/cleaned_and_verified.csv
# 📝 Missing images logged to: /home/yash/Desktop/project/new dataset/ft3/missing_images_log.txt
# ✅ Found 11010 images
# ❌ Missing 0 images

# %%
import os
import shutil
import pandas as pd

# Define your input folders and CSV files
folders = [
    '/home/yash/Desktop/project/new dataset/ft1',
    '/home/yash/Desktop/project/new dataset/ft2',
    '/home/yash/Desktop/project/new dataset/ft3'
]
csv_files = [
    '/home/yash/Desktop/project/new dataset/ft1/main_labels.csv',
    '/home/yash/Desktop/project/new dataset/ft2/main_labels.csv',
    '/home/yash/Desktop/project/new dataset/ft3/main_labels.csv'
]

# Define output folder and output CSV
output_folder = '/home/yash/Desktop/project/new dataset/final'
output_csv = '/home/yash/Desktop/project/new dataset/final/main_labels.csv'

# Create the output folder if it doesn't exist
os.makedirs(output_folder, exist_ok=True)

# List to store all label dataframes
all_labels = []

for folder, csv_file in zip(folders, csv_files):
    # Load the CSV
    try:
        df = pd.read_csv(csv_file, on_bad_lines='skip')
    except Exception as e:
        print(f"⚠️ Error reading {csv_file}: {e}")
        continue

    updated_filenames = []

    # Move images and update filenames if needed
    for filename in df['filename']:
        src_path = os.path.join(folder, filename)

        # Check if the file actually exists
        if not os.path.isfile(src_path):
            print(f"⚠️ Skipping missing or invalid file: {src_path}")
            updated_filenames.append(None)  # Mark this as missing
            continue

        dst_path = os.path.join(output_folder, filename)
        new_filename = filename

        # If filename already exists, rename it to avoid conflict
        if os.path.exists(dst_path):
            base, ext = os.path.splitext(filename)
            counter = 1
            while os.path.exists(dst_path):
                new_filename = f"{base}_{counter}{ext}"
                dst_path = os.path.join(output_folder, new_filename)
                counter += 1

        # Copy the file
        shutil.copy2(src_path, dst_path)
        updated_filenames.append(new_filename)

    # Update the DataFrame with possibly new filenames
    df['filename'] = updated_filenames

    # Drop rows where filename was missing
    df = df.dropna(subset=['filename'])

    # Append the cleaned DataFrame
    all_labels.append(df)

# Merge all the cleaned dataframes
merged_df = pd.concat(all_labels, ignore_index=True)

# Save the final merged CSV
merged_df.to_csv(output_csv, index=False)

print("\n✅ Merging complete!")
print(f"📂 Images are saved in: {output_folder}")
print(f"📝 Combined labels CSV saved as: {output_csv}")
# Out:
# ✅ Merging complete!
# 📂 Images are saved in: /home/yash/Desktop/project/new dataset/final
# 📝 Combined labels CSV saved as: /home/yash/Desktop/project/new dataset/final/main_labels.csv

# %%
import os

# List of CSV file paths you want to fix
csv_files = [
    '/home/yash/Desktop/project/new dataset/ft1/main_labels.csv',
    '/home/yash/Desktop/project/new dataset/ft2/main_labels.csv',
    '/home/yash/Desktop/project/new dataset/ft3/main_labels.csv'
]

# Set to True if you want to overwrite the original files
overwrite_original = True

for csv_file in csv_files:
    if not os.path.isfile(csv_file):
        print(f"⚠️ File not found: {csv_file}")
        continue

    print(f"Processing: {csv_file}")

    fixed_lines = []

    with open(csv_file, 'r', encoding='utf-8') as file:
        lines = file.readlines()

    # Process header
    header = lines[0].strip().split(',')
    if len(header) < 2 or header[0].lower() != 'filename':
        print(f"⚠️ Unexpected CSV format in: {csv_file}")
        continue

    fixed_lines.append('filename,labels\n')

    # Process each row
    for line in lines[1:]:
        parts = line.strip().split(',')

        # Ensure there is at least a filename and one label
        if len(parts) < 2:
            print(f"⚠️ Skipping malformed line: {line.strip()}")
            continue

        filename = parts[0]
        labels = ','.join(parts[1:])  # Combine all remaining parts into one label string
        labels = f"\"{labels}\""      # Wrap labels in double quotes

        fixed_line = f"{filename},{labels}\n"
        fixed_lines.append(fixed_line)

    # Determine output file path
    if overwrite_original:
        output_path = csv_file  # Overwrite original file
    else:
        folder, name = os.path.split(csv_file)
        output_path = os.path.join(folder, f"fixed_{name}")

    # Save the fixed CSV
    with open(output_path, 'w', encoding='utf-8') as file:
        file.writelines(fixed_lines)

    print(f"✅ Fixed CSV saved at: {output_path}")

print("\n🎉 All done!")
# Out:
# Processing: /home/yash/Desktop/project/new dataset/ft1/main_labels.csv
# ✅ Fixed CSV saved at: /home/yash/Desktop/project/new dataset/ft1/main_labels.csv
# Processing: /home/yash/Desktop/project/new dataset/ft2/main_labels.csv
# ✅ Fixed CSV saved at: /home/yash/Desktop/project/new dataset/ft2/main_labels.csv
# Processing: /home/yash/Desktop/project/new dataset/ft3/main_labels.csv
# ✅ Fixed CSV saved at: /home/yash/Desktop/project/new dataset/ft3/main_labels.csv
#
# 🎉 All done!

# %%
import os
import pandas as pd

# Paths
final_folder = '/home/yash/Desktop/project/new dataset/final'
final_csv = '/home/yash/Desktop/project/new dataset/final/main_labels.csv'

# Load the CSV
df = pd.read_csv(final_csv)

# List of images mentioned in CSV
csv_filenames = set(df['filename'])

# List of images actually present in the folder
folder_filenames = set(f for f in os.listdir(final_folder) if f.lower().endswith(('.jpg', '.jpeg', '.png')))

# Check for missing images
missing_in_folder = csv_filenames - folder_filenames
extra_in_folder = folder_filenames - csv_filenames

# Results
print("\n🔎 Verification Results:")

if not missing_in_folder:
    print("✅ All images listed in CSV exist in the folder!")
else:
    print(f"❌ {len(missing_in_folder)} images listed in CSV are missing in the folder:")
    for missing_file in missing_in_folder:
        print(f"   - {missing_file}")

if not extra_in_folder:
    print("✅ No extra images found in the folder!")
else:
    print(f"⚠️ {len(extra_in_folder)} extra images found in the folder that are not in the CSV:")
    for extra_file in extra_in_folder:
        print(f"   - {extra_file}")

print("\n🎯 Verification complete!")
# Out:
# 🔎 Verification Results:
# ✅ All images listed in CSV exist in the folder!
# ✅ No extra images found in the folder!
#
# 🎯 Verification complete!

# %%
import os
import zipfile

# Path of the final folder you want to zip
final_folder = '/home/yash/Desktop/project/new dataset/final'

# Path for the zip file to be created
zip_file_path = '/home/yash/Desktop/project/new dataset/final_dataset.zip'

# Create a zip file
with zipfile.ZipFile(zip_file_path, 'w', zipfile.ZIP_DEFLATED) as zipf:
    # Walk through the folder to add all files
    for root, dirs, files in os.walk(final_folder):
        for file in files:
            file_path = os.path.join(root, file)
            arcname = os.path.relpath(file_path, final_folder)  # Save with relative paths
            zipf.write(file_path, arcname)

print(f"✅ The folder and its contents have been successfully zipped as: {zip_file_path}")
# Out:
# ✅ The folder and its contents have been successfully zipped as: /home/yash/Desktop/project/new dataset/final_dataset.zip
